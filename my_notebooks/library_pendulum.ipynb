# %% [markdown]
# # Linear Inverted Pendulum with Wall, Hybrid MPC Demo

# %% [markdown]
# This is a demo for the Model Predictive Control (MPC) package $\texttt{mpc_tools}$.

# %%
# %load_ext autoreload
# %autoreload 2
#%pylab notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pympc.dynamical_systems as ds
import pympc.plot as mpc_plt
from pympc.control import HybridModelPredictiveController
from pympc.approximated_controller_full_feasible_sets import ApproximatedHybridModelPredictiveController, PolicySampler, upload_PolicySampler
from pympc.geometry.polytope import Polytope

# %% [markdown]
# # Dynamics

# %% [markdown]
# We stabilize a linear inverted pendulum with mass $m$ and length $l$, subject to the gravity acceleration $g$. The pendulum is allowed to impact with an elastic wall (with stiffness $k$) placed at distance $d$ from the vertical line passing trough the hinge.

# %%
m = 1.
l = 1.
g = 10.
k = 1000.
d = .1
t_s = .01

# %% [markdown]
# We express the linearized dynamics in PieceWise Affine (PWA) form:
# \begin{equation}
# \dot x =
# \begin{cases}
# A_1 x + B_1 u + c_1, \quad \text{if} \quad (x, u) \in \mathcal D_1, \\
# A_2 x + B_2 u + c_2, \quad \text{if} \quad (x, u) \in \mathcal D_2,
# \end{cases}
# \end{equation}
#
# with
#
# \begin{equation}
# A_1 =
# \begin{bmatrix}
# 0 & 1 \\ g/l & 0
# \end{bmatrix},
# \quad
# B_1 =
# \begin{bmatrix}
# 0 \\ 1/(ml^2)
# \end{bmatrix},
# \quad
# c_1 =
# \begin{bmatrix}
# 0 \\ 0
# \end{bmatrix},
# \end{equation}
#
# \begin{equation}
# \mathcal D_1 =
# \{ (x,u) \ | \ x_1 \leq d/l, \ x_{min} \leq x \leq x_{max}, \ u_{min} \leq u \leq u_{max} \},
# \end{equation}
#
# \begin{equation}
# A_2 =
# \begin{bmatrix}
# 0 & 1 \\ g/l - k/m & 0
# \end{bmatrix},
# \quad
# B_2 =
# \begin{bmatrix}
# 0 \\ 1/(ml^2)
# \end{bmatrix},
# \quad
# c_2 =
# \begin{bmatrix}
# 0 \\ kd/(ml)
# \end{bmatrix},
# \end{equation}
#
# \begin{equation}
# \mathcal D_2 =
# \{ (x,u) \ | \ x_1 > d/l, \ x_{min} \leq x \leq x_{max}, \ u_{min} \leq u \leq u_{max} \},
# \end{equation}
#
#
# The discrete-time PWA system can be defined from its continuous-time representation setting a sampling time $t_s$.

# %%
# discretization method
method = 'explicit_euler'

# dynamics n.1
A_1 = np.array([[0., 1.],[g/l, 0.]])
B_1 = np.array([[0.],[1/(m*l**2.)]])
c_1 = np.array([[0.],[0.]])
S_1 = ds.AffineSystem.from_continuous(A_1, B_1, c_1, t_s, method)

# dynamics n.2
A_2 = np.array([[0., 1.],[g/l-k/m, 0.]])
B_2 = B_1
c_2 = np.array([[0.],[k*d/(m*l)]])
S_2 = ds.AffineSystem.from_continuous(A_2, B_2, c_2, t_s, method)

# list of dynamics
S = [S_1, S_2]

# %% [markdown]
# The domains of the PWA have to be expressed as polytopes.

# %%
# state domain n.1
x_max_1 = np.array([[d/l], [1.]])
x_min_1 = -np.array([[d/l*1.2],[x_max_1[1,0]]])
X_1 = Polytope.from_bounds(x_min_1, x_max_1)
X_1.assemble()

# state domain n.2
x_min_2 = np.array([[x_max_1[0,0]], [x_min_1[1,0]]])
x_max_2 = -x_min_1
X_2 = Polytope.from_bounds(x_min_2, x_max_2)
X_2.assemble()

# list of state domains
X = [X_1, X_2]

# input domain
u_max = np.array([[4.]])
u_min = -u_max
U = Polytope.from_bounds(u_min, u_max)
U.assemble()
U = [U]*2

# %% [markdown]
# We can now define the PWA system.

# %%
pwa_sys = ds.PieceWiseAffineSystem.from_orthogonal_domains(S, X, U)

# %% [markdown]
# # MPC controller

# %% [markdown]
# At each each step, the following optimal control is solved
# \begin{align}
# \min \quad &
# \sum_{k=0}^{N-1} (x_k^T Q x_k + u_k^T R u_k) + x_N^T P x_N \\
# \text{subject to} \quad &
# x_{k+1} =
# \begin{cases}
# A_1 x_k + B_1 u_k + c_1, \quad \text{if} \quad (x_k, u_k) \in \mathcal D_1, \\
# A_2 x_k + B_2 u_k + c_2, \quad \text{if} \quad (x_k, u_k) \in \mathcal D_2,
# \end{cases}, \\
# & (x_k, u_k) \in \mathcal D_1 \cup \mathcal D_2, \quad k = 1,2,\ldots,N-1, \\
# & x_N \in \mathcal X_N, \\
# & x_0 \ \text{given}, \\
# \end{align}
# and the input $u_0$ is applied to the system.

# %%
# controller parameters
N = 10
Q = np.eye(A_1.shape[0])
R = np.eye(B_1.shape[1])
objective_norm = 'two'

# terminal set and cost
P, K = ds.dare(S[0].A, S[0].B, Q, R)
X_N = ds.moas_closed_loop_from_orthogonal_domains(S[0].A, S[0].B, K, X[0], U[0])

# hybrid controller
gurobi_parameters = {'OutputFlag': False}
controller = HybridModelPredictiveController(pwa_sys, N, objective_norm, Q, R, P, X_N, gurobi_parameters)
# Out:
# Computation of Maximal Invariant Constraint-Admissible Set started.
# Determinedness index: 23, Convergence index: -8.2567687914e-05, Number of facets: 120.
# Maximal Invariant Constraint-Admissible Set found.
# Removing redundant facets ... minimal facets are 45.

# %% [markdown]
# We can now simulate the closed-loop dynamics startion from the initial state $x_0$.

# %%
N_sim = 100
x_0 = np.array([[.05],[.52]])
u = []
x = [x_0]
for k in range(N_sim):
    print('Time step ' + str(k) + '.\r'),
    u.append(controller.feedback(x[k]))
    x_next = pwa_sys.simulate(x[k], [u[k]])[0][1]
    x.append(x_next)
# Out:
# Time step 99.

# %% [markdown]
# We can use the plot functions to visualize the time evolution of the system.

# %%
mpc_plt.input_sequence(u, t_s, (u_min, u_max))
plt.show()
mpc_plt.state_trajectory(x, t_s, (x_min_1, x_min_2, x_max_2))
plt.show()

# %% [markdown]
# # Approximate MPC controller

# %% [markdown]
# Construction of the library

# %%
terminal_mode = 0
n_samples = 10000
sampler = PolicySampler(controller)
sampler.sample_policy(n_samples)
sampler.save('library_pendulum_' + str(n_samples))
# Out:
# Sample 0:
# solving MIQP...  time spent: 0.00405597686768 s, model status: OPTIMAL.
# QP condensed.
# Sample 1:
# rejected.
# Sample 2:
# rejected.
# Sample 3:
# solving MIQP...  time spent: 0.00146818161011 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 4:
# rejected.
# Sample 5:
# solving MIQP...  time spent: 0.000643968582153 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 6:
# rejected.
# Sample 7:
# rejected.
# Sample 8:
# rejected.
# Sample 9:
# rejected.
# Sample 10:
# solving MIQP...  time spent: 0.00284004211426 s, model status: OPTIMAL.
# QP condensed.
# Sample 11:
# rejected.
# Sample 12:
# rejected.
# Sample 13:
# solving MIQP...  time spent: 0.000760078430176 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 14:
# rejected.
# Sample 15:
# rejected.
# Sample 16:
# rejected.
# Sample 17:
# rejected.
# Sample 18:
# solving MIQP...  time spent: 0.000684022903442 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 19:
# solving MIQP...  time spent: 0.00131607055664 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 20:
# solving MIQP...  time spent: 0.00229716300964 s, model status: OPTIMAL.
# QP condensed.
# Sample 21:
# rejected.
# Sample 22:
# rejected.
# Sample 23:
# rejected.
# Sample 24:
# solving MIQP...  time spent: 0.00129699707031 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 25:
# rejected.
# Sample 26:
# rejected.
# Sample 27:
# rejected.
# Sample 28:
# rejected.
# Sample 29:
# rejected.
# Sample 30:
# rejected.
# Sample 31:
# rejected.
# Sample 32:
# solving MIQP...  time spent: 0.000706911087036 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 33:
# rejected.
# Sample 34:
# rejected.
# Sample 35:
# rejected.
# Sample 36:
# rejected.
# Sample 37:
# solving MIQP...  time spent: 0.000917911529541 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 38:
# solving MIQP...  time spent: 0.00452280044556 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 39:
# solving MIQP...  time spent: 0.000965118408203 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 40:
# rejected.
# Sample 41:
# rejected.
# Sample 42:
# rejected.
# Sample 43:
# rejected.
# Sample 44:
# rejected.
# Sample 45:
# rejected.
# Sample 46:
# solving MIQP...  time spent: 0.00742602348328 s, model status: OPTIMAL.
# QP condensed.
# Sample 47:
# rejected.
# Sample 48:
# solving MIQP...  time spent: 0.000915050506592 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 49:
# solving MIQP...  time spent: 0.000918865203857 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 50:
# rejected.
# Sample 51:
# rejected.
# Sample 52:
# solving MIQP...  time spent: 0.000982046127319 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 53:
# rejected.
# Sample 54:
# rejected.
# Sample 55:
# solving MIQP...  time spent: 0.00106287002563 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 56:
# rejected.
# Sample 57:
# rejected.
# Sample 58:
# rejected.
# Sample 59:
# rejected.
# Sample 60:
# rejected.
# Sample 61:
# rejected.
# Sample 62:
# rejected.
# Sample 63:
# rejected.
# Sample 64:
# solving MIQP...  time spent: 0.00183796882629 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 65:
# rejected.
# Sample 66:
# solving MIQP...  time spent: 0.00920915603638 s, model status: OPTIMAL.
# QP condensed.
# Sample 67:
# rejected.
# Sample 68:
# rejected.
# Sample 69:
# rejected.
# Sample 70:
# rejected.
# Sample 71:
# rejected.
# Sample 72:
# rejected.
# Sample 73:
# rejected.
# Sample 74:
# rejected.
# Sample 75:
# rejected.
# Sample 76:
# rejected.
# Sample 77:
# rejected.
# Sample 78:
# rejected.
# Sample 79:
# rejected.
# Sample 80:
# rejected.
# Sample 81:
# solving MIQP...  time spent: 0.000761032104492 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 82:
# rejected.
# Sample 83:
# rejected.
# Sample 84:
# solving MIQP...  time spent: 0.000712156295776 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 85:
# rejected.
# Sample 86:
# rejected.
# Sample 87:
# rejected.
# Sample 88:
# rejected.
# Sample 89:
# rejected.
# Sample 90:
# solving MIQP...  time spent: 0.00220799446106 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 91:
# rejected.
# Sample 92:
# solving MIQP...  time spent: 0.00281000137329 s, model status: OPTIMAL.
# QP condensed.
# Sample 93:
# rejected.
# Sample 94:
# solving MIQP...  time spent: 0.000829935073853 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 95:
# rejected.
# Sample 96:
# solving MIQP...  time spent: 0.001296043396 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 97:
# rejected.
# Sample 98:
# rejected.
# Sample 99:
# rejected.
# Sample 100:
# rejected.
# Sample 101:
# rejected.
# Sample 102:
# rejected.
# Sample 103:
# rejected.
# Sample 104:
# rejected.
# Sample 105:
# rejected.
# Sample 106:
# rejected.
# Sample 107:
# solving MIQP...  time spent: 0.000731945037842 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 108:
# rejected.
# Sample 109:
# rejected.
# Sample 110:
# rejected.
# Sample 111:
# solving MIQP...  time spent: 0.000572919845581 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 112:
# rejected.
# Sample 113:
# rejected.
# Sample 114:
# rejected.
# Sample 115:
# solving MIQP...  time spent: 0.000568151473999 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 116:
# solving MIQP...  time spent: 0.000556945800781 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 117:
# rejected.
# Sample 118:
# rejected.
# Sample 119:
# solving MIQP...  time spent: 0.000554084777832 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 120:
# rejected.
# Sample 121:
# rejected.
# Sample 122:
# solving MIQP...  time spent: 0.00189900398254 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 123:
# solving MIQP...  time spent: 0.0011990070343 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 124:
# rejected.
# Sample 125:
# rejected.
# Sample 126:
# rejected.
# Sample 127:
# rejected.
# Sample 128:
# solving MIQP...  time spent: 0.00139594078064 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 129:
# solving MIQP...  time spent: 0.000568151473999 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 130:
# rejected.
# Sample 131:
# rejected.
# Sample 132:
# rejected.
# Sample 133:
# rejected.
# Sample 134:
# rejected.
# Sample 135:
# rejected.
# Sample 136:
# solving MIQP...  time spent: 0.000694990158081 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 137:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 138:
# rejected.
# Sample 139:
# solving MIQP...  time spent: 0.000617980957031 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 140:
# rejected.
# Sample 141:
# rejected.
# Sample 142:
# solving MIQP...  time spent: 0.00234293937683 s, model status: OPTIMAL.
# QP condensed.
# Sample 143:
# rejected.
# Sample 144:
# rejected.
# Sample 145:
# rejected.
# Sample 146:
# solving MIQP...  time spent: 0.000716924667358 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 147:
# rejected.
# Sample 148:
# rejected.
# Sample 149:
# rejected.
# Sample 150:
# rejected.
# Sample 151:
# solving MIQP...  time spent: 0.000649929046631 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 152:
# solving MIQP...  time spent: 0.000665903091431 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 153:
# rejected.
# Sample 154:
# rejected.
# Sample 155:
# rejected.
# Sample 156:
# rejected.
# Sample 157:
# rejected.
# Sample 158:
# rejected.
# Sample 159:
# rejected.
# Sample 160:
# rejected.
# Sample 161:
# solving MIQP...  time spent: 0.00571298599243 s, model status: OPTIMAL.
# QP condensed.
# Sample 162:
# rejected.
# Sample 163:
# rejected.
# Sample 164:
# rejected.
# Sample 165:
# rejected.
# Sample 166:
# rejected.
# Sample 167:
# rejected.
# Sample 168:
# rejected.
# Sample 169:
# solving MIQP...  time spent: 0.000849008560181 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 170:
# rejected.
# Sample 171:
# rejected.
# Sample 172:
# rejected.
# Sample 173:
# rejected.
# Sample 174:
# rejected.
# Sample 175:
# rejected.
# Sample 176:
# rejected.
# Sample 177:
# rejected.
# Sample 178:
# rejected.
# Sample 179:
# rejected.
# Sample 180:
# rejected.
# Sample 181:
# solving MIQP...  time spent: 0.0072169303894 s, model status: OPTIMAL.
# QP condensed.
# Sample 182:
# rejected.
# Sample 183:
# rejected.
# Sample 184:
# solving MIQP...  time spent: 0.000747919082642 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 185:
# solving MIQP...  time spent: 0.000625133514404 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 186:
# solving MIQP...  time spent: 0.000657081604004 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 187:
# rejected.
# Sample 188:
# rejected.
# Sample 189:
# rejected.
# Sample 190:
# rejected.
# Sample 191:
# rejected.
# Sample 192:
# rejected.
# Sample 193:
# solving MIQP...  time spent: 0.000690937042236 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 194:
# rejected.
# Sample 195:
# rejected.
# Sample 196:
# rejected.
# Sample 197:
# solving MIQP...  time spent: 0.000730991363525 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 198:
# rejected.
# Sample 199:
# rejected.
# Sample 200:
# rejected.
# Sample 201:
# rejected.
# Sample 202:
# solving MIQP...  time spent: 0.000625848770142 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 203:
# rejected.
# Sample 204:
# solving MIQP...  time spent: 0.000846862792969 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 205:
# rejected.
# Sample 206:
# rejected.
# Sample 207:
# rejected.
# Sample 208:
# solving MIQP...  time spent: 0.000670909881592 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 209:
# rejected.
# Sample 210:
# solving MIQP...  time spent: 0.00123906135559 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 211:
# rejected.
# Sample 212:
# rejected.
# Sample 213:
# rejected.
# Sample 214:
# rejected.
# Sample 215:
# rejected.
# Sample 216:
# rejected.
# Sample 217:
# rejected.
# Sample 218:
# rejected.
# Sample 219:
# rejected.
# Sample 220:
# rejected.
# Sample 221:
# rejected.
# Sample 222:
# rejected.
# Sample 223:
# solving MIQP...  time spent: 0.000697135925293 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 224:
# solving MIQP...  time spent: 0.000591993331909 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 225:
# rejected.
# Sample 226:
# solving MIQP...  time spent: 0.00126099586487 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 227:
# rejected.
# Sample 228:
# rejected.
# Sample 229:
# solving MIQP...  time spent: 0.000609874725342 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 230:
# rejected.
# Sample 231:
# solving MIQP...  time spent: 0.000581026077271 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 232:
# rejected.
# Sample 233:
# rejected.
# Sample 234:
# solving MIQP...  time spent: 0.000653982162476 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 235:
# solving MIQP...  time spent: 0.000654935836792 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 236:
# rejected.
# Sample 237:
# rejected.
# Sample 238:
# rejected.
# Sample 239:
# rejected.
# Sample 240:
# solving MIQP...  time spent: 0.00067400932312 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 241:
# solving MIQP...  time spent: 0.000684976577759 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 242:
# rejected.
# Sample 243:
# rejected.
# Sample 244:
# rejected.
# Sample 245:
# solving MIQP...  time spent: 0.00218796730042 s, model status: OPTIMAL.
# QP condensed.
# Sample 246:
# rejected.
# Sample 247:
# solving MIQP...  time spent: 0.00078296661377 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 248:
# rejected.
# Sample 249:
# solving MIQP...  time spent: 0.000673055648804 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 250:
# solving MIQP...  time spent: 0.00121903419495 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 251:
# rejected.
# Sample 252:
# rejected.
# Sample 253:
# solving MIQP...  time spent: 0.000694036483765 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 254:
# rejected.
# Sample 255:
# rejected.
# Sample 256:
# solving MIQP...  time spent: 0.00126194953918 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 257:
# rejected.
# Sample 258:
# rejected.
# Sample 259:
# rejected.
# Sample 260:
# rejected.
# Sample 261:
# rejected.
# Sample 262:
# rejected.
# Sample 263:
# solving MIQP...  time spent: 0.000581979751587 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 264:
# rejected.
# Sample 265:
# rejected.
# Sample 266:
# rejected.
# Sample 267:
# rejected.
# Sample 268:
# rejected.
# Sample 269:
# rejected.
# Sample 270:
# rejected.
# Sample 271:
# rejected.
# Sample 272:
# rejected.
# Sample 273:
# rejected.
# Sample 274:
# rejected.
# Sample 275:
# rejected.
# Sample 276:
# solving MIQP...  time spent: 0.00112700462341 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 277:
# rejected.
# Sample 278:
# rejected.
# Sample 279:
# solving MIQP...  time spent: 0.0013120174408 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 280:
# solving MIQP...  time spent: 0.000576972961426 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 281:
# solving MIQP...  time spent: 0.00121784210205 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 282:
# rejected.
# Sample 283:
# rejected.
# Sample 284:
# rejected.
# Sample 285:
# rejected.
# Sample 286:
# rejected.
# Sample 287:
# rejected.
# Sample 288:
# rejected.
# Sample 289:
# solving MIQP...  time spent: 0.000684022903442 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 290:
# rejected.
# Sample 291:
# rejected.
# Sample 292:
# rejected.
# Sample 293:
# solving MIQP...  time spent: 0.000638008117676 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 294:
# rejected.
# Sample 295:
# rejected.
# Sample 296:
# rejected.
# Sample 297:
# rejected.
# Sample 298:
# rejected.
# Sample 299:
# rejected.
# Sample 300:
# rejected.
# Sample 301:
# solving MIQP...  time spent: 0.000606775283813 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 302:
# rejected.
# Sample 303:
# solving MIQP...  time spent: 0.00217008590698 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 304:
# rejected.
# Sample 305:
# rejected.
# Sample 306:
# solving MIQP...  time spent: 0.0012321472168 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 307:
# rejected.
# Sample 308:
# rejected.
# Sample 309:
# rejected.
# Sample 310:
# rejected.
# Sample 311:
# rejected.
# Sample 312:
# solving MIQP...  time spent: 0.000663995742798 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 313:
# solving MIQP...  time spent: 0.00152516365051 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 314:
# rejected.
# Sample 315:
# solving MIQP...  time spent: 0.000629901885986 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 316:
# rejected.
# Sample 317:
# solving MIQP...  time spent: 0.000579118728638 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 318:
# rejected.
# Sample 319:
# rejected.
# Sample 320:
# rejected.
# Sample 321:
# rejected.
# Sample 322:
# rejected.
# Sample 323:
# rejected.
# Sample 324:
# rejected.
# Sample 325:
# rejected.
# Sample 326:
# solving MIQP...  time spent: 0.000575065612793 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 327:
# solving MIQP...  time spent: 0.00059700012207 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 328:
# rejected.
# Sample 329:
# solving MIQP...  time spent: 0.000685930252075 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 330:
# rejected.
# Sample 331:
# rejected.
# Sample 332:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 333:
# rejected.
# Sample 334:
# rejected.
# Sample 335:
# solving MIQP...  time spent: 0.000575065612793 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 336:
# solving MIQP...  time spent: 0.000583171844482 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 337:
# rejected.
# Sample 338:
# rejected.
# Sample 339:
# solving MIQP...  time spent: 0.000608921051025 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 340:
# rejected.
# Sample 341:
# solving MIQP...  time spent: 0.000641822814941 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 342:
# rejected.
# Sample 343:
# rejected.
# Sample 344:
# solving MIQP...  time spent: 0.000686883926392 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 345:
# solving MIQP...  time spent: 0.00068998336792 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 346:
# rejected.
# Sample 347:
# rejected.
# Sample 348:
# rejected.
# Sample 349:
# rejected.
# Sample 350:
# rejected.
# Sample 351:
# solving MIQP...  time spent: 0.000622987747192 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 352:
# solving MIQP...  time spent: 0.00209093093872 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 353:
# rejected.
# Sample 354:
# rejected.
# Sample 355:
# rejected.
# Sample 356:
# rejected.
# Sample 357:
# rejected.
# Sample 358:
# rejected.
# Sample 359:
# rejected.
# Sample 360:
# solving MIQP...  time spent: 0.000679016113281 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 361:
# rejected.
# Sample 362:
# rejected.
# Sample 363:
# solving MIQP...  time spent: 0.000570058822632 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 364:
# rejected.
# Sample 365:
# rejected.
# Sample 366:
# solving MIQP...  time spent: 0.000643014907837 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 367:
# rejected.
# Sample 368:
# rejected.
# Sample 369:
# rejected.
# Sample 370:
# rejected.
# Sample 371:
# rejected.
# Sample 372:
# rejected.
# Sample 373:
# rejected.
# Sample 374:
# rejected.
# Sample 375:
# rejected.
# Sample 376:
# solving MIQP...  time spent: 0.000694036483765 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 377:
# rejected.
# Sample 378:
# rejected.
# Sample 379:
# rejected.
# Sample 380:
# rejected.
# Sample 381:
# rejected.
# Sample 382:
# rejected.
# Sample 383:
# rejected.
# Sample 384:
# rejected.
# Sample 385:
# rejected.
# Sample 386:
# rejected.
# Sample 387:
# rejected.
# Sample 388:
# solving MIQP...  time spent: 0.000771999359131 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 389:
# rejected.
# Sample 390:
# rejected.
# Sample 391:
# rejected.
# Sample 392:
# rejected.
# Sample 393:
# rejected.
# Sample 394:
# solving MIQP...  time spent: 0.000656843185425 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 395:
# rejected.
# Sample 396:
# rejected.
# Sample 397:
# rejected.
# Sample 398:
# rejected.
# Sample 399:
# rejected.
# Sample 400:
# solving MIQP...  time spent: 0.000588893890381 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 401:
# rejected.
# Sample 402:
# rejected.
# Sample 403:
# rejected.
# Sample 404:
# rejected.
# Sample 405:
# rejected.
# Sample 406:
# rejected.
# Sample 407:
# rejected.
# Sample 408:
# rejected.
# Sample 409:
# rejected.
# Sample 410:
# solving MIQP...  time spent: 0.000694036483765 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 411:
# solving MIQP...  time spent: 0.000601053237915 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 412:
# rejected.
# Sample 413:
# solving MIQP...  time spent: 0.00068187713623 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 414:
# solving MIQP...  time spent: 0.00123500823975 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 415:
# solving MIQP...  time spent: 0.000646829605103 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 416:
# rejected.
# Sample 417:
# rejected.
# Sample 418:
# solving MIQP...  time spent: 0.000657081604004 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 419:
# rejected.
# Sample 420:
# rejected.
# Sample 421:
# rejected.
# Sample 422:
# rejected.
# Sample 423:
# rejected.
# Sample 424:
# rejected.
# Sample 425:
# solving MIQP...  time spent: 0.000642061233521 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 426:
# rejected.
# Sample 427:
# rejected.
# Sample 428:
# rejected.
# Sample 429:
# rejected.
# Sample 430:
# rejected.
# Sample 431:
# solving MIQP...  time spent: 0.00068998336792 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 432:
# rejected.
# Sample 433:
# rejected.
# Sample 434:
# rejected.
# Sample 435:
# rejected.
# Sample 436:
# solving MIQP...  time spent: 0.00057315826416 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 437:
# rejected.
# Sample 438:
# solving MIQP...  time spent: 0.000625133514404 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 439:
# rejected.
# Sample 440:
# solving MIQP...  time spent: 0.000590801239014 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 441:
# rejected.
# Sample 442:
# rejected.
# Sample 443:
# solving MIQP...  time spent: 0.000648975372314 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 444:
# solving MIQP...  time spent: 0.000607967376709 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 445:
# rejected.
# Sample 446:
# rejected.
# Sample 447:
# rejected.
# Sample 448:
# rejected.
# Sample 449:
# rejected.
# Sample 450:
# rejected.
# Sample 451:
# rejected.
# Sample 452:
# rejected.
# Sample 453:
# rejected.
# Sample 454:
# rejected.
# Sample 455:
# rejected.
# Sample 456:
# rejected.
# Sample 457:
# rejected.
# Sample 458:
# rejected.
# Sample 459:
# solving MIQP...  time spent: 0.00127792358398 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 460:
# solving MIQP...  time spent: 0.000578880310059 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 461:
# rejected.
# Sample 462:
# solving MIQP...  time spent: 0.000726938247681 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 463:
# rejected.
# Sample 464:
# rejected.
# Sample 465:
# rejected.
# Sample 466:
# solving MIQP...  time spent: 0.00081992149353 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 467:
# solving MIQP...  time spent: 0.000689029693604 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 468:
# solving MIQP...  time spent: 0.000640869140625 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 469:
# rejected.
# Sample 470:
# solving MIQP...  time spent: 0.000688076019287 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 471:
# solving MIQP...  time spent: 0.000983953475952 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 472:
# rejected.
# Sample 473:
# rejected.
# Sample 474:
# rejected.
# Sample 475:
# solving MIQP...  time spent: 0.00091290473938 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 476:
# solving MIQP...  time spent: 0.000644207000732 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 477:
# rejected.
# Sample 478:
# solving MIQP...  time spent: 0.000602006912231 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 479:
# rejected.
# Sample 480:
# rejected.
# Sample 481:
# rejected.
# Sample 482:
# solving MIQP...  time spent: 0.000683069229126 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 483:
# solving MIQP...  time spent: 0.000541925430298 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 484:
# solving MIQP...  time spent: 0.00123715400696 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 485:
# solving MIQP...  time spent: 0.000952005386353 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 486:
# rejected.
# Sample 487:
# solving MIQP...  time spent: 0.00158190727234 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 488:
# rejected.
# Sample 489:
# rejected.
# Sample 490:
# rejected.
# Sample 491:
# solving MIQP...  time spent: 0.000678062438965 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 492:
# rejected.
# Sample 493:
# rejected.
# Sample 494:
# solving MIQP...  time spent: 0.000648975372314 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 495:
# rejected.
# Sample 496:
# rejected.
# Sample 497:
# rejected.
# Sample 498:
# rejected.
# Sample 499:
# rejected.
# Sample 500:
# rejected.
# Sample 501:
# rejected.
# Sample 502:
# rejected.
# Sample 503:
# rejected.
# Sample 504:
# rejected.
# Sample 505:
# rejected.
# Sample 506:
# rejected.
# Sample 507:
# rejected.
# Sample 508:
# solving MIQP...  time spent: 0.000592947006226 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 509:
# solving MIQP...  time spent: 0.000607013702393 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 510:
# rejected.
# Sample 511:
# solving MIQP...  time spent: 0.00166702270508 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 512:
# solving MIQP...  time spent: 0.00126004219055 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 513:
# rejected.
# Sample 514:
# rejected.
# Sample 515:
# rejected.
# Sample 516:
# rejected.
# Sample 517:
# rejected.
# Sample 518:
# solving MIQP...  time spent: 0.000708818435669 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 519:
# rejected.
# Sample 520:
# rejected.
# Sample 521:
# rejected.
# Sample 522:
# rejected.
# Sample 523:
# rejected.
# Sample 524:
# rejected.
# Sample 525:
# rejected.
# Sample 526:
# rejected.
# Sample 527:
# rejected.
# Sample 528:
# solving MIQP...  time spent: 0.000667095184326 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 529:
# rejected.
# Sample 530:
# rejected.
# Sample 531:
# rejected.
# Sample 532:
# rejected.
# Sample 533:
# rejected.
# Sample 534:
# rejected.
# Sample 535:
# rejected.
# Sample 536:
# rejected.
# Sample 537:
# rejected.
# Sample 538:
# solving MIQP...  time spent: 0.000605821609497 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 539:
# rejected.
# Sample 540:
# rejected.
# Sample 541:
# rejected.
# Sample 542:
# rejected.
# Sample 543:
# rejected.
# Sample 544:
# solving MIQP...  time spent: 0.00136089324951 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 545:
# rejected.
# Sample 546:
# solving MIQP...  time spent: 0.00272297859192 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 547:
# solving MIQP...  time spent: 0.000667810440063 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 548:
# rejected.
# Sample 549:
# rejected.
# Sample 550:
# rejected.
# Sample 551:
# solving MIQP...  time spent: 0.000614166259766 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 552:
# rejected.
# Sample 553:
# rejected.
# Sample 554:
# rejected.
# Sample 555:
# rejected.
# Sample 556:
# solving MIQP...  time spent: 0.000610113143921 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 557:
# rejected.
# Sample 558:
# rejected.
# Sample 559:
# rejected.
# Sample 560:
# rejected.
# Sample 561:
# rejected.
# Sample 562:
# solving MIQP...  time spent: 0.00117588043213 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 563:
# rejected.
# Sample 564:
# solving MIQP...  time spent: 0.000705003738403 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 565:
# rejected.
# Sample 566:
# solving MIQP...  time spent: 0.00220704078674 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 567:
# rejected.
# Sample 568:
# rejected.
# Sample 569:
# solving MIQP...  time spent: 0.000715017318726 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 570:
# rejected.
# Sample 571:
# rejected.
# Sample 572:
# solving MIQP...  time spent: 0.000707864761353 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 573:
# rejected.
# Sample 574:
# solving MIQP...  time spent: 0.000700950622559 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 575:
# rejected.
# Sample 576:
# rejected.
# Sample 577:
# rejected.
# Sample 578:
# rejected.
# Sample 579:
# solving MIQP...  time spent: 0.00133800506592 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 580:
# solving MIQP...  time spent: 0.000671148300171 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 581:
# solving MIQP...  time spent: 0.000626087188721 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 582:
# solving MIQP...  time spent: 0.000648021697998 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 583:
# rejected.
# Sample 584:
# rejected.
# Sample 585:
# rejected.
# Sample 586:
# rejected.
# Sample 587:
# rejected.
# Sample 588:
# rejected.
# Sample 589:
# rejected.
# Sample 590:
# rejected.
# Sample 591:
# rejected.
# Sample 592:
# rejected.
# Sample 593:
# rejected.
# Sample 594:
# rejected.
# Sample 595:
# rejected.
# Sample 596:
# rejected.
# Sample 597:
# rejected.
# Sample 598:
# rejected.
# Sample 599:
# rejected.
# Sample 600:
# solving MIQP...  time spent: 0.00330400466919 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 601:
# rejected.
# Sample 602:
# solving MIQP...  time spent: 0.000664949417114 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 603:
# rejected.
# Sample 604:
# rejected.
# Sample 605:
# rejected.
# Sample 606:
# rejected.
# Sample 607:
# rejected.
# Sample 608:
# rejected.
# Sample 609:
# solving MIQP...  time spent: 0.000617027282715 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 610:
# solving MIQP...  time spent: 0.00220394134521 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 611:
# rejected.
# Sample 612:
# rejected.
# Sample 613:
# rejected.
# Sample 614:
# rejected.
# Sample 615:
# rejected.
# Sample 616:
# solving MIQP...  time spent: 0.000705003738403 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 617:
# rejected.
# Sample 618:
# rejected.
# Sample 619:
# rejected.
# Sample 620:
# rejected.
# Sample 621:
# solving MIQP...  time spent: 0.000735998153687 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 622:
# solving MIQP...  time spent: 0.000703096389771 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 623:
# rejected.
# Sample 624:
# rejected.
# Sample 625:
# solving MIQP...  time spent: 0.000643014907837 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 626:
# rejected.
# Sample 627:
# rejected.
# Sample 628:
# rejected.
# Sample 629:
# rejected.
# Sample 630:
# solving MIQP...  time spent: 0.000730037689209 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 631:
# rejected.
# Sample 632:
# rejected.
# Sample 633:
# rejected.
# Sample 634:
# rejected.
# Sample 635:
# rejected.
# Sample 636:
# rejected.
# Sample 637:
# rejected.
# Sample 638:
# rejected.
# Sample 639:
# rejected.
# Sample 640:
# rejected.
# Sample 641:
# solving MIQP...  time spent: 0.000631809234619 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 642:
# solving MIQP...  time spent: 0.00213098526001 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 643:
# rejected.
# Sample 644:
# solving MIQP...  time spent: 0.000676870346069 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 645:
# rejected.
# Sample 646:
# rejected.
# Sample 647:
# rejected.
# Sample 648:
# rejected.
# Sample 649:
# rejected.
# Sample 650:
# rejected.
# Sample 651:
# solving MIQP...  time spent: 0.000638008117676 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 652:
# rejected.
# Sample 653:
# rejected.
# Sample 654:
# rejected.
# Sample 655:
# rejected.
# Sample 656:
# rejected.
# Sample 657:
# solving MIQP...  time spent: 0.000688076019287 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 658:
# solving MIQP...  time spent: 0.000586986541748 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 659:
# rejected.
# Sample 660:
# rejected.
# Sample 661:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 662:
# rejected.
# Sample 663:
# solving MIQP...  time spent: 0.00223207473755 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 664:
# rejected.
# Sample 665:
# solving MIQP...  time spent: 0.00133895874023 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 666:
# rejected.
# Sample 667:
# rejected.
# Sample 668:
# rejected.
# Sample 669:
# rejected.
# Sample 670:
# rejected.
# Sample 671:
# solving MIQP...  time spent: 0.00130701065063 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 672:
# rejected.
# Sample 673:
# rejected.
# Sample 674:
# rejected.
# Sample 675:
# rejected.
# Sample 676:
# rejected.
# Sample 677:
# rejected.
# Sample 678:
# rejected.
# Sample 679:
# solving MIQP...  time spent: 0.000617027282715 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 680:
# solving MIQP...  time spent: 0.00264811515808 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 681:
# solving MIQP...  time spent: 0.000731945037842 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 682:
# rejected.
# Sample 683:
# rejected.
# Sample 684:
# rejected.
# Sample 685:
# rejected.
# Sample 686:
# solving MIQP...  time spent: 0.000720024108887 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 687:
# rejected.
# Sample 688:
# rejected.
# Sample 689:
# rejected.
# Sample 690:
# solving MIQP...  time spent: 0.000868797302246 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 691:
# rejected.
# Sample 692:
# rejected.
# Sample 693:
# rejected.
# Sample 694:
# rejected.
# Sample 695:
# rejected.
# Sample 696:
# solving MIQP...  time spent: 0.00125908851624 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 697:
# solving MIQP...  time spent: 0.00340509414673 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 698:
# rejected.
# Sample 699:
# rejected.
# Sample 700:
# solving MIQP...  time spent: 0.000762939453125 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 701:
# rejected.
# Sample 702:
# rejected.
# Sample 703:
# rejected.
# Sample 704:
# rejected.
# Sample 705:
# rejected.
# Sample 706:
# rejected.
# Sample 707:
# rejected.
# Sample 708:
# rejected.
# Sample 709:
# rejected.
# Sample 710:
# rejected.
# Sample 711:
# rejected.
# Sample 712:
# solving MIQP...  time spent: 0.00212597846985 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 713:
# rejected.
# Sample 714:
# rejected.
# Sample 715:
# rejected.
# Sample 716:
# rejected.
# Sample 717:
# rejected.
# Sample 718:
# rejected.
# Sample 719:
# rejected.
# Sample 720:
# rejected.
# Sample 721:
# rejected.
# Sample 722:
# rejected.
# Sample 723:
# rejected.
# Sample 724:
# rejected.
# Sample 725:
# rejected.
# Sample 726:
# rejected.
# Sample 727:
# rejected.
# Sample 728:
# solving MIQP...  time spent: 0.000752210617065 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 729:
# solving MIQP...  time spent: 0.000724077224731 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 730:
# rejected.
# Sample 731:
# rejected.
# Sample 732:
# rejected.
# Sample 733:
# rejected.
# Sample 734:
# rejected.
# Sample 735:
# rejected.
# Sample 736:
# solving MIQP...  time spent: 0.000717163085938 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 737:
# rejected.
# Sample 738:
# rejected.
# Sample 739:
# rejected.
# Sample 740:
# solving MIQP...  time spent: 0.000962972640991 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 741:
# rejected.
# Sample 742:
# solving MIQP...  time spent: 0.000662088394165 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 743:
# solving MIQP...  time spent: 0.000581979751587 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 744:
# rejected.
# Sample 745:
# solving MIQP...  time spent: 0.00126004219055 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 746:
# rejected.
# Sample 747:
# solving MIQP...  time spent: 0.00222182273865 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 748:
# rejected.
# Sample 749:
# rejected.
# Sample 750:
# solving MIQP...  time spent: 0.000748157501221 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 751:
# rejected.
# Sample 752:
# solving MIQP...  time spent: 0.000715017318726 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 753:
# rejected.
# Sample 754:
# rejected.
# Sample 755:
# rejected.
# Sample 756:
# solving MIQP...  time spent: 0.000808000564575 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 757:
# rejected.
# Sample 758:
# rejected.
# Sample 759:
# rejected.
# Sample 760:
# solving MIQP...  time spent: 0.000610113143921 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 761:
# rejected.
# Sample 762:
# solving MIQP...  time spent: 0.00171494483948 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 763:
# rejected.
# Sample 764:
# rejected.
# Sample 765:
# rejected.
# Sample 766:
# rejected.
# Sample 767:
# rejected.
# Sample 768:
# rejected.
# Sample 769:
# solving MIQP...  time spent: 0.000759840011597 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 770:
# solving MIQP...  time spent: 0.000739097595215 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 771:
# rejected.
# Sample 772:
# rejected.
# Sample 773:
# solving MIQP...  time spent: 0.000591993331909 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 774:
# solving MIQP...  time spent: 0.00071907043457 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 775:
# rejected.
# Sample 776:
# solving MIQP...  time spent: 0.000919103622437 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 777:
# rejected.
# Sample 778:
# solving MIQP...  time spent: 0.000669002532959 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 779:
# solving MIQP...  time spent: 0.000696182250977 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 780:
# rejected.
# Sample 781:
# rejected.
# Sample 782:
# rejected.
# Sample 783:
# rejected.
# Sample 784:
# rejected.
# Sample 785:
# rejected.
# Sample 786:
# rejected.
# Sample 787:
# rejected.
# Sample 788:
# rejected.
# Sample 789:
# rejected.
# Sample 790:
# rejected.
# Sample 791:
# solving MIQP...  time spent: 0.000990867614746 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 792:
# rejected.
# Sample 793:
# rejected.
# Sample 794:
# rejected.
# Sample 795:
# rejected.
# Sample 796:
# rejected.
# Sample 797:
# rejected.
# Sample 798:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 799:
# solving MIQP...  time spent: 0.000711917877197 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 800:
# rejected.
# Sample 801:
# rejected.
# Sample 802:
# solving MIQP...  time spent: 0.000693798065186 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 803:
# rejected.
# Sample 804:
# solving MIQP...  time spent: 0.000868797302246 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 805:
# rejected.
# Sample 806:
# rejected.
# Sample 807:
# solving MIQP...  time spent: 0.00251889228821 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 808:
# rejected.
# Sample 809:
# rejected.
# Sample 810:
# rejected.
# Sample 811:
# rejected.
# Sample 812:
# rejected.
# Sample 813:
# rejected.
# Sample 814:
# rejected.
# Sample 815:
# rejected.
# Sample 816:
# rejected.
# Sample 817:
# rejected.
# Sample 818:
# solving MIQP...  time spent: 0.000692129135132 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 819:
# solving MIQP...  time spent: 0.000635147094727 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 820:
# rejected.
# Sample 821:
# rejected.
# Sample 822:
# solving MIQP...  time spent: 0.000777959823608 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 823:
# rejected.
# Sample 824:
# rejected.
# Sample 825:
# rejected.
# Sample 826:
# rejected.
# Sample 827:
# rejected.
# Sample 828:
# rejected.
# Sample 829:
# rejected.
# Sample 830:
# rejected.
# Sample 831:
# rejected.
# Sample 832:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 833:
# rejected.
# Sample 834:
# rejected.
# Sample 835:
# rejected.
# Sample 836:
# rejected.
# Sample 837:
# solving MIQP...  time spent: 0.000627040863037 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 838:
# rejected.
# Sample 839:
# rejected.
# Sample 840:
# rejected.
# Sample 841:
# rejected.
# Sample 842:
# rejected.
# Sample 843:
# rejected.
# Sample 844:
# rejected.
# Sample 845:
# rejected.
# Sample 846:
# rejected.
# Sample 847:
# rejected.
# Sample 848:
# rejected.
# Sample 849:
# solving MIQP...  time spent: 0.00154614448547 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 850:
# solving MIQP...  time spent: 0.000622034072876 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 851:
# rejected.
# Sample 852:
# rejected.
# Sample 853:
# rejected.
# Sample 854:
# solving MIQP...  time spent: 0.00064492225647 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 855:
# rejected.
# Sample 856:
# solving MIQP...  time spent: 0.000593900680542 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 857:
# rejected.
# Sample 858:
# rejected.
# Sample 859:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 860:
# solving MIQP...  time spent: 0.00081992149353 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 861:
# rejected.
# Sample 862:
# rejected.
# Sample 863:
# rejected.
# Sample 864:
# rejected.
# Sample 865:
# rejected.
# Sample 866:
# rejected.
# Sample 867:
# rejected.
# Sample 868:
# rejected.
# Sample 869:
# rejected.
# Sample 870:
# rejected.
# Sample 871:
# rejected.
# Sample 872:
# rejected.
# Sample 873:
# rejected.
# Sample 874:
# solving MIQP...  time spent: 0.000653028488159 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 875:
# rejected.
# Sample 876:
# rejected.
# Sample 877:
# rejected.
# Sample 878:
# solving MIQP...  time spent: 0.000580072402954 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 879:
# rejected.
# Sample 880:
# rejected.
# Sample 881:
# rejected.
# Sample 882:
# rejected.
# Sample 883:
# rejected.
# Sample 884:
# rejected.
# Sample 885:
# rejected.
# Sample 886:
# rejected.
# Sample 887:
# rejected.
# Sample 888:
# rejected.
# Sample 889:
# rejected.
# Sample 890:
# solving MIQP...  time spent: 0.000789880752563 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 891:
# rejected.
# Sample 892:
# rejected.
# Sample 893:
# rejected.
# Sample 894:
# rejected.
# Sample 895:
# solving MIQP...  time spent: 0.000633955001831 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 896:
# rejected.
# Sample 897:
# rejected.
# Sample 898:
# rejected.
# Sample 899:
# rejected.
# Sample 900:
# solving MIQP...  time spent: 0.00148010253906 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 901:
# rejected.
# Sample 902:
# rejected.
# Sample 903:
# solving MIQP...  time spent: 0.000807046890259 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 904:
# solving MIQP...  time spent: 0.000933885574341 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 905:
# rejected.
# Sample 906:
# solving MIQP...  time spent: 0.000690937042236 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 907:
# rejected.
# Sample 908:
# rejected.
# Sample 909:
# solving MIQP...  time spent: 0.000698089599609 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 910:
# solving MIQP...  time spent: 0.00276899337769 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 911:
# rejected.
# Sample 912:
# solving MIQP...  time spent: 0.00143909454346 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 913:
# rejected.
# Sample 914:
# solving MIQP...  time spent: 0.00125503540039 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 915:
# rejected.
# Sample 916:
# rejected.
# Sample 917:
# rejected.
# Sample 918:
# solving MIQP...  time spent: 0.000632047653198 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 919:
# solving MIQP...  time spent: 0.000668048858643 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 920:
# solving MIQP...  time spent: 0.00062894821167 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 921:
# rejected.
# Sample 922:
# rejected.
# Sample 923:
# rejected.
# Sample 924:
# rejected.
# Sample 925:
# rejected.
# Sample 926:
# rejected.
# Sample 927:
# rejected.
# Sample 928:
# rejected.
# Sample 929:
# rejected.
# Sample 930:
# rejected.
# Sample 931:
# rejected.
# Sample 932:
# rejected.
# Sample 933:
# rejected.
# Sample 934:
# solving MIQP...  time spent: 0.000603914260864 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 935:
# rejected.
# Sample 936:
# rejected.
# Sample 937:
# rejected.
# Sample 938:
# solving MIQP...  time spent: 0.000703096389771 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 939:
# rejected.
# Sample 940:
# rejected.
# Sample 941:
# solving MIQP...  time spent: 0.00133085250854 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 942:
# solving MIQP...  time spent: 0.00146317481995 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 943:
# rejected.
# Sample 944:
# rejected.
# Sample 945:
# rejected.
# Sample 946:
# solving MIQP...  time spent: 0.00118207931519 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 947:
# rejected.
# Sample 948:
# rejected.
# Sample 949:
# solving MIQP...  time spent: 0.000939130783081 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 950:
# solving MIQP...  time spent: 0.000623941421509 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 951:
# rejected.
# Sample 952:
# rejected.
# Sample 953:
# rejected.
# Sample 954:
# rejected.
# Sample 955:
# rejected.
# Sample 956:
# rejected.
# Sample 957:
# solving MIQP...  time spent: 0.00243711471558 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 958:
# rejected.
# Sample 959:
# rejected.
# Sample 960:
# rejected.
# Sample 961:
# rejected.
# Sample 962:
# solving MIQP...  time spent: 0.00127196311951 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 963:
# rejected.
# Sample 964:
# rejected.
# Sample 965:
# rejected.
# Sample 966:
# solving MIQP...  time spent: 0.00154900550842 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 967:
# solving MIQP...  time spent: 0.000690937042236 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 968:
# rejected.
# Sample 969:
# rejected.
# Sample 970:
# rejected.
# Sample 971:
# solving MIQP...  time spent: 0.00117802619934 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 972:
# rejected.
# Sample 973:
# rejected.
# Sample 974:
# rejected.
# Sample 975:
# rejected.
# Sample 976:
# solving MIQP...  time spent: 0.000699043273926 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 977:
# rejected.
# Sample 978:
# solving MIQP...  time spent: 0.00130891799927 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 979:
# rejected.
# Sample 980:
# rejected.
# Sample 981:
# rejected.
# Sample 982:
# rejected.
# Sample 983:
# rejected.
# Sample 984:
# rejected.
# Sample 985:
# solving MIQP...  time spent: 0.00067400932312 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 986:
# rejected.
# Sample 987:
# solving MIQP...  time spent: 0.000723123550415 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 988:
# solving MIQP...  time spent: 0.00268816947937 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 989:
# solving MIQP...  time spent: 0.000705003738403 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 990:
# rejected.
# Sample 991:
# rejected.
# Sample 992:
# rejected.
# Sample 993:
# rejected.
# Sample 994:
# rejected.
# Sample 995:
# rejected.
# Sample 996:
# rejected.
# Sample 997:
# rejected.
# Sample 998:
# rejected.
# Sample 999:
# rejected.
# Sample 1000:
# solving MIQP...  time spent: 0.000703096389771 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 1001:
# rejected.
# Sample 1002:
# rejected.
# Sample 1003:
# rejected.
# Sample 1004:
# solving MIQP...  time spent: 0.000813007354736 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 1005:
# ...
# rejected.
# Sample 9684:
# solving MIQP...  time spent: 0.000622987747192 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9685:
# rejected.
# Sample 9686:
# solving MIQP...  time spent: 0.00081992149353 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9687:
# rejected.
# Sample 9688:
# rejected.
# Sample 9689:
# solving MIQP...  time spent: 0.000654935836792 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9690:
# rejected.
# Sample 9691:
# rejected.
# Sample 9692:
# solving MIQP...  time spent: 0.000587940216064 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9693:
# rejected.
# Sample 9694:
# rejected.
# Sample 9695:
# rejected.
# Sample 9696:
# solving MIQP...  time spent: 0.000888109207153 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9697:
# rejected.
# Sample 9698:
# rejected.
# Sample 9699:
# rejected.
# Sample 9700:
# solving MIQP...  time spent: 0.000856876373291 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9701:
# rejected.
# Sample 9702:
# solving MIQP...  time spent: 0.00385594367981 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9703:
# rejected.
# Sample 9704:
# rejected.
# Sample 9705:
# rejected.
# Sample 9706:
# rejected.
# Sample 9707:
# rejected.
# Sample 9708:
# solving MIQP...  time spent: 0.000791072845459 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9709:
# solving MIQP...  time spent: 0.00120377540588 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9710:
# rejected.
# Sample 9711:
# solving MIQP...  time spent: 0.000715970993042 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9712:
# rejected.
# Sample 9713:
# solving MIQP...  time spent: 0.000658988952637 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9714:
# rejected.
# Sample 9715:
# rejected.
# Sample 9716:
# solving MIQP...  time spent: 0.000693798065186 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9717:
# solving MIQP...  time spent: 0.000894784927368 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9718:
# solving MIQP...  time spent: 0.000900983810425 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9719:
# solving MIQP...  time spent: 0.00122690200806 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9720:
# rejected.
# Sample 9721:
# solving MIQP...  time spent: 0.00107288360596 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9722:
# rejected.
# Sample 9723:
# rejected.
# Sample 9724:
# solving MIQP...  time spent: 0.000622034072876 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9725:
# solving MIQP...  time spent: 0.000801801681519 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9726:
# rejected.
# Sample 9727:
# rejected.
# Sample 9728:
# rejected.
# Sample 9729:
# rejected.
# Sample 9730:
# rejected.
# Sample 9731:
# rejected.
# Sample 9732:
# solving MIQP...  time spent: 0.000791072845459 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9733:
# rejected.
# Sample 9734:
# rejected.
# Sample 9735:
# rejected.
# Sample 9736:
# rejected.
# Sample 9737:
# rejected.
# Sample 9738:
# rejected.
# Sample 9739:
# rejected.
# Sample 9740:
# rejected.
# Sample 9741:
# solving MIQP...  time spent: 0.00130796432495 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9742:
# solving MIQP...  time spent: 0.000883102416992 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9743:
# rejected.
# Sample 9744:
# rejected.
# Sample 9745:
# rejected.
# Sample 9746:
# rejected.
# Sample 9747:
# rejected.
# Sample 9748:
# solving MIQP...  time spent: 0.000792026519775 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9749:
# rejected.
# Sample 9750:
# rejected.
# Sample 9751:
# rejected.
# Sample 9752:
# rejected.
# Sample 9753:
# rejected.
# Sample 9754:
# rejected.
# Sample 9755:
# rejected.
# Sample 9756:
# rejected.
# Sample 9757:
# rejected.
# Sample 9758:
# rejected.
# Sample 9759:
# rejected.
# Sample 9760:
# solving MIQP...  time spent: 0.000608921051025 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9761:
# rejected.
# Sample 9762:
# solving MIQP...  time spent: 0.000689029693604 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9763:
# solving MIQP...  time spent: 0.00125694274902 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9764:
# rejected.
# Sample 9765:
# rejected.
# Sample 9766:
# rejected.
# Sample 9767:
# rejected.
# Sample 9768:
# rejected.
# Sample 9769:
# rejected.
# Sample 9770:
# rejected.
# Sample 9771:
# solving MIQP...  time spent: 0.000650882720947 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9772:
# rejected.
# Sample 9773:
# rejected.
# Sample 9774:
# rejected.
# Sample 9775:
# rejected.
# Sample 9776:
# rejected.
# Sample 9777:
# solving MIQP...  time spent: 0.000705003738403 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9778:
# rejected.
# Sample 9779:
# solving MIQP...  time spent: 0.000591039657593 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9780:
# solving MIQP...  time spent: 0.00151491165161 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9781:
# solving MIQP...  time spent: 0.00132012367249 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9782:
# rejected.
# Sample 9783:
# rejected.
# Sample 9784:
# solving MIQP...  time spent: 0.00070595741272 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9785:
# rejected.
# Sample 9786:
# solving MIQP...  time spent: 0.000634908676147 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9787:
# rejected.
# Sample 9788:
# rejected.
# Sample 9789:
# rejected.
# Sample 9790:
# solving MIQP...  time spent: 0.000643014907837 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9791:
# rejected.
# Sample 9792:
# rejected.
# Sample 9793:
# solving MIQP...  time spent: 0.000647068023682 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9794:
# solving MIQP...  time spent: 0.00132989883423 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9795:
# rejected.
# Sample 9796:
# solving MIQP...  time spent: 0.000585079193115 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9797:
# rejected.
# Sample 9798:
# rejected.
# Sample 9799:
# rejected.
# Sample 9800:
# rejected.
# Sample 9801:
# solving MIQP...  time spent: 0.000650882720947 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9802:
# solving MIQP...  time spent: 0.000664949417114 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9803:
# solving MIQP...  time spent: 0.000590801239014 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9804:
# rejected.
# Sample 9805:
# solving MIQP...  time spent: 0.000643014907837 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9806:
# solving MIQP...  time spent: 0.000622034072876 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9807:
# rejected.
# Sample 9808:
# rejected.
# Sample 9809:
# rejected.
# Sample 9810:
# rejected.
# Sample 9811:
# rejected.
# Sample 9812:
# rejected.
# Sample 9813:
# rejected.
# Sample 9814:
# rejected.
# Sample 9815:
# rejected.
# Sample 9816:
# solving MIQP...  time spent: 0.000769138336182 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9817:
# rejected.
# Sample 9818:
# rejected.
# Sample 9819:
# solving MIQP...  time spent: 0.000817060470581 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9820:
# rejected.
# Sample 9821:
# rejected.
# Sample 9822:
# solving MIQP...  time spent: 0.00250196456909 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9823:
# rejected.
# Sample 9824:
# solving MIQP...  time spent: 0.000718832015991 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9825:
# rejected.
# Sample 9826:
# solving MIQP...  time spent: 0.000631093978882 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9827:
# rejected.
# Sample 9828:
# solving MIQP...  time spent: 0.000648021697998 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9829:
# rejected.
# Sample 9830:
# solving MIQP...  time spent: 0.000690937042236 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9831:
# rejected.
# Sample 9832:
# rejected.
# Sample 9833:
# rejected.
# Sample 9834:
# rejected.
# Sample 9835:
# rejected.
# Sample 9836:
# solving MIQP...  time spent: 0.00075888633728 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9837:
# rejected.
# Sample 9838:
# rejected.
# Sample 9839:
# rejected.
# Sample 9840:
# rejected.
# Sample 9841:
# rejected.
# Sample 9842:
# solving MIQP...  time spent: 0.000631093978882 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9843:
# rejected.
# Sample 9844:
# rejected.
# Sample 9845:
# rejected.
# Sample 9846:
# rejected.
# Sample 9847:
# rejected.
# Sample 9848:
# rejected.
# Sample 9849:
# rejected.
# Sample 9850:
# rejected.
# Sample 9851:
# rejected.
# Sample 9852:
# solving MIQP...  time spent: 0.0012149810791 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9853:
# rejected.
# Sample 9854:
# rejected.
# Sample 9855:
# rejected.
# Sample 9856:
# rejected.
# Sample 9857:
# rejected.
# Sample 9858:
# rejected.
# Sample 9859:
# rejected.
# Sample 9860:
# solving MIQP...  time spent: 0.000684976577759 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9861:
# rejected.
# Sample 9862:
# rejected.
# Sample 9863:
# rejected.
# Sample 9864:
# rejected.
# Sample 9865:
# rejected.
# Sample 9866:
# rejected.
# Sample 9867:
# rejected.
# Sample 9868:
# rejected.
# Sample 9869:
# rejected.
# Sample 9870:
# rejected.
# Sample 9871:
# rejected.
# Sample 9872:
# rejected.
# Sample 9873:
# rejected.
# Sample 9874:
# rejected.
# Sample 9875:
# rejected.
# Sample 9876:
# rejected.
# Sample 9877:
# solving MIQP...  time spent: 0.00073504447937 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9878:
# solving MIQP...  time spent: 0.000629901885986 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9879:
# rejected.
# Sample 9880:
# solving MIQP...  time spent: 0.000582933425903 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9881:
# rejected.
# Sample 9882:
# rejected.
# Sample 9883:
# rejected.
# Sample 9884:
# solving MIQP...  time spent: 0.00123500823975 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9885:
# rejected.
# Sample 9886:
# rejected.
# Sample 9887:
# rejected.
# Sample 9888:
# solving MIQP...  time spent: 0.00086498260498 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9889:
# rejected.
# Sample 9890:
# rejected.
# Sample 9891:
# rejected.
# Sample 9892:
# rejected.
# Sample 9893:
# rejected.
# Sample 9894:
# rejected.
# Sample 9895:
# rejected.
# Sample 9896:
# rejected.
# Sample 9897:
# rejected.
# Sample 9898:
# rejected.
# Sample 9899:
# rejected.
# Sample 9900:
# solving MIQP...  time spent: 0.0012731552124 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9901:
# rejected.
# Sample 9902:
# solving MIQP...  time spent: 0.000689029693604 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9903:
# solving MIQP...  time spent: 0.000668048858643 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9904:
# solving MIQP...  time spent: 0.000753879547119 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9905:
# rejected.
# Sample 9906:
# rejected.
# Sample 9907:
# rejected.
# Sample 9908:
# rejected.
# Sample 9909:
# solving MIQP...  time spent: 0.000675201416016 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9910:
# rejected.
# Sample 9911:
# rejected.
# Sample 9912:
# rejected.
# Sample 9913:
# rejected.
# Sample 9914:
# rejected.
# Sample 9915:
# rejected.
# Sample 9916:
# rejected.
# Sample 9917:
# rejected.
# Sample 9918:
# rejected.
# Sample 9919:
# rejected.
# Sample 9920:
# rejected.
# Sample 9921:
# rejected.
# Sample 9922:
# rejected.
# Sample 9923:
# rejected.
# Sample 9924:
# rejected.
# Sample 9925:
# solving MIQP...  time spent: 0.000815868377686 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9926:
# solving MIQP...  time spent: 0.00155997276306 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9927:
# rejected.
# Sample 9928:
# rejected.
# Sample 9929:
# solving MIQP...  time spent: 0.000857830047607 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9930:
# rejected.
# Sample 9931:
# rejected.
# Sample 9932:
# rejected.
# Sample 9933:
# solving MIQP...  time spent: 0.00255012512207 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9934:
# rejected.
# Sample 9935:
# rejected.
# Sample 9936:
# solving MIQP...  time spent: 0.000643968582153 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9937:
# rejected.
# Sample 9938:
# rejected.
# Sample 9939:
# solving MIQP...  time spent: 0.000648021697998 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9940:
# solving MIQP...  time spent: 0.000651121139526 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9941:
# solving MIQP...  time spent: 0.000728130340576 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9942:
# rejected.
# Sample 9943:
# solving MIQP...  time spent: 0.00126695632935 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9944:
# solving MIQP...  time spent: 0.000581979751587 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9945:
# rejected.
# Sample 9946:
# rejected.
# Sample 9947:
# rejected.
# Sample 9948:
# rejected.
# Sample 9949:
# rejected.
# Sample 9950:
# rejected.
# Sample 9951:
# solving MIQP...  time spent: 0.00262999534607 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9952:
# solving MIQP...  time spent: 0.00171399116516 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9953:
# solving MIQP...  time spent: 0.000710010528564 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9954:
# rejected.
# Sample 9955:
# rejected.
# Sample 9956:
# rejected.
# Sample 9957:
# rejected.
# Sample 9958:
# rejected.
# Sample 9959:
# rejected.
# Sample 9960:
# rejected.
# Sample 9961:
# rejected.
# Sample 9962:
# rejected.
# Sample 9963:
# rejected.
# Sample 9964:
# rejected.
# Sample 9965:
# solving MIQP...  time spent: 0.00499892234802 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9966:
# rejected.
# Sample 9967:
# rejected.
# Sample 9968:
# rejected.
# Sample 9969:
# solving MIQP...  time spent: 0.00102210044861 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9970:
# rejected.
# Sample 9971:
# rejected.
# Sample 9972:
# solving MIQP...  time spent: 0.000720977783203 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9973:
# rejected.
# Sample 9974:
# rejected.
# Sample 9975:
# solving MIQP...  time spent: 0.000637054443359 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9976:
# rejected.
# Sample 9977:
# solving MIQP...  time spent: 0.000696897506714 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9978:
# rejected.
# Sample 9979:
# rejected.
# Sample 9980:
# rejected.
# Sample 9981:
# solving MIQP...  time spent: 0.000766038894653 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9982:
# rejected.
# Sample 9983:
# rejected.
# Sample 9984:
# rejected.
# Sample 9985:
# solving MIQP...  time spent: 0.000871181488037 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9986:
# solving MIQP...  time spent: 0.000616788864136 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9987:
# rejected.
# Sample 9988:
# rejected.
# Sample 9989:
# rejected.
# Sample 9990:
# solving MIQP...  time spent: 0.00121212005615 s, model status: INFEASIBLE OR UNBOUNDED.
# problem unfeasible.
# Sample 9991:
# rejected.
# Sample 9992:
# rejected.
# Sample 9993:
# rejected.
# Sample 9994:
# rejected.
# Sample 9995:
# rejected.
# Sample 9996:
# rejected.
# Sample 9997:
# rejected.
# Sample 9998:
# rejected.
# Sample 9999:
# rejected.
#
# Total number of samples: 10000, switching sequences found: 13, rejected samples: 7332, unfeasible samples: 2655.

# %% [markdown]
# samples_so_far = 100
# sampler = upload_PolicySampler('library_pendulum_' + str(samples_so_far))

# %%
fig = plt.figure(figsize=(6,3))
X_1.plot(facecolor='w', linestyle='--')
plt.text(.08,.8,r'$\mathcal{D}_1$')
X_2.plot(facecolor='w', linestyle='--')
plt.text(.105,.8,r'$\mathcal{D}_2$')
sampler.plot_partition()
#fig.savefig('sample_pendulum.pdf', bbox_inches='tight')
plt.show()
# Out:
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 7, vertices found so far 7, length of the last inflation 3.999550e-04.
# Projection derived 0.314172029495 seconds: number of facets is 7, number of vertices is 7.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 7, vertices found so far 7, length of the last inflation 2.499700e-04.
# Projection derived 0.292805194855 seconds: number of facets is 7, number of vertices is 7.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 68, vertices found so far 68, length of the last inflation 5.655983e-05.
# Projection derived 3.71178388596 seconds: number of facets is 68, number of vertices is 68.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 16, vertices found so far 16, length of the last inflation 4.722643e-04.
# Projection derived 0.739035129547 seconds: number of facets is 16, number of vertices is 16.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 12, vertices found so far 12, length of the last inflation 7.487556e-05.
# Projection derived 0.531895160675 seconds: number of facets is 12, number of vertices is 12.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 6, vertices found so far 6, length of the last inflation 9.296165e-04.
# Projection derived 0.252566099167 seconds: number of facets is 6, number of vertices is 6.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 8, vertices found so far 8, length of the last inflation 1.128042e-04.
# Projection derived 0.325176000595 seconds: number of facets is 8, number of vertices is 8.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 13, vertices found so far 13, length of the last inflation 5.404721e-04.
# Projection derived 0.609562158585 seconds: number of facets is 13, number of vertices is 13.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 11, vertices found so far 11, length of the last inflation 9.576605e-04.
# Projection derived 0.521171808243 seconds: number of facets is 11, number of vertices is 11.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 5, vertices found so far 5, length of the last inflation 5.636186e-04.
# Projection derived 0.237755060196 seconds: number of facets is 5, number of vertices is 5.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 9, vertices found so far 9, length of the last inflation 2.951652e-04.
# Projection derived 0.393622159958 seconds: number of facets is 9, number of vertices is 9.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 4, vertices found so far 4, length of the last inflation 2.095291e-01.
# Projection derived 0.178246021271 seconds: number of facets is 4, number of vertices is 4.
# *** Convex Hull Method for Orthogonal Projections STOP ***
#
#
# *** Convex Hull Method for Orthogonal Projections START ***
# Inner 2D simplex found.
# Expansion of the inner polytope started.
# Facets found so far 6, vertices found so far 6, length of the last inflation 1.614557e-03.
# Projection derived 0.293844938278 seconds: number of facets is 6, number of vertices is 6.
# *** Convex Hull Method for Orthogonal Projections STOP ***

# %%
approximated_controller = ApproximatedHybridModelPredictiveController(sampler, terminal_mode)

# %%
approximated_controller.tree.plot('inverted_pendulum_tree')

# %%
u = []
x = [x_0]
ms_ws = None
for k in range(N_sim):
    print '\nTime step ' + str(k) + ':'
    u_k, ms_ws = approximated_controller.feedback(x[k], ms_ws)
    ms_ws = ms_ws[1:] + (terminal_mode,)
    x_next = pwa_sys.simulate(x[k], [u_k])[0][1]
    u.append(u_k)
    x.append(x_next)

# %%
mpc_plt.input_sequence(u, t_s, (u_min, u_max))
plt.show()
mpc_plt.state_trajectory(x, t_s, (x_min_1, x_min_2, x_max_2))
plt.show()
