# %% [markdown]
# # Model Predictive Control Demo

# %% [markdown]
# This is a demo for the Model Predictive Control (MPC) package $\texttt{mpc_tools}$.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpc_tools as mpc
import mpcqp as mqp

# %% [markdown]
# ## Linear Inverted Pendulum

# %% [markdown]
# Here we stibilize a linear inverted pendulum with mass $m$ and length $l$, subject to the gravity acceleration $g$.

# %%
m = 1.
l = 1.
g = 10.

# %% [markdown]
# The linearized continuous-time dynamics is
# \begin{equation}
# \dot x = A x + B u =
# \begin{bmatrix}
# 0 & 1 \\ g/l & 0
# \end{bmatrix}
# x +
# \begin{bmatrix}
# 0 \\ 1/(ml^2)
# \end{bmatrix}
# u.
# \end{equation}
# The discrete-time linear system can be defined from its continuous-time representation setting a sampling time $t_s$ (the exact zero-order-hold discretization is used).

# %%
A = np.array([
    [0., 1.],
    [g/l, 0.]
])
B = np.array([
    [0.],
    [1/(m*l**2.)]
])
t_s = .1
sys = mpc.DTLinearSystem.from_continuous(t_s, A, B)

# %% [markdown]
# At each each step, the following optimal control is solved
# \begin{align}
# \min \quad &
# \sum_{k=0}^{N-1} (x_k^T Q x_k + u_k^T R u_k) + x_N^T P x_N \\
# \text{subject to} \quad & x_{k+1} = A x_k + B u_k, \quad k = 0,1,\ldots,N-1, \\
# & x_0 \ \text{given}, \\
# & u_k \in \mathcal U, \quad k = 0,1,\ldots,N-1, \\
# & x_k \in \mathcal X, \quad k = 1,2,\ldots,N-1, \\
# & x_N \in \mathcal X_N, \\
# \end{align}
# By default $P=Q$ but, for staibility reasons, sometimes it's preferable to use the solution of the Discrete Algebraic Ricccati Equation (DARE)
# \begin{equation}
# P = (A+BK)^T P (A+BK) + Q + K^T R K
# \end{equation}
# where $K = -(B^T P B + R)^{-1} B^T P A$ is the optimal feedback $u_k = K x_k$.
# This can be done setting $\texttt{terminal_cost = 'dare'}$.

# %%
N = 5
Q = np.eye(A.shape[0])/100.
R = np.eye(B.shape[1])
terminal_cost = 'dare'
# controller = mpc.MPCController(sys, N, Q, R, terminal_cost)
factory = mqp.MPCQPFactory(sys, N, Q, R, terminal_cost)

# %% [markdown]
# Input and state constraints have to be linear and they can be enforced as bounds (e.g., $u_{max} \geq u_k \geq u_{min}$) or as generic linear inqualities (e.g., $C u_k \leq C$).

# %%
x_max = np.array([[np.pi/6.], [np.pi/20./(N*t_s)]])
x_min = -x_max
factory.add_state_bound(x_max, x_min)
u_max = np.array([[m*g*l*np.pi/8.]])
u_min = -u_max
factory.add_input_bound(u_max, u_min)

# %% [markdown]
# To ensure stability of the closed loop system two terminal constraints are available:
#
# 1) $\texttt{terminal_constraint = 'origin'}$: this option imposes $x_N = 0$ which is sufficient to ensure stability (regardless the terminal cost) but in most cases it's excessive.
#
# 2) $\texttt{terminal_constraint = 'moas'}$: this option imposes $\mathcal{X}_N \in \mathcal{O}_{\infty}$ where $\mathcal{O}_{\infty}$ denotes the Maximum Output Admissible Set for the system closed loop system $x_{k+1} = (A + BK) x_k$, with $K$ derived from the DARE.
# Mathematically speaking, we have that $x_N \in \mathcal{O}_{\infty} \Leftrightarrow \{ x_k \in \mathcal{X} \wedge u_k \in \mathcal{U} \} \ \forall k \geq N$.
# This constraint, if coupoled with the DARE terminal cost, is sufficient condition for the stability of the closed loop system.

# %%
terminal_constraint = 'moas'
factory.set_terminal_constraint(terminal_constraint)

# %% [markdown]
# We now assemble the controller and simulate the closed loop system for $N_{sim}$ steps starting from the initial condition $x_0$.

# %%
qp = factory.assemble()
controller = mpc.MPCController(qp, sys.n_u)
N_sim = 50
x_0 = np.array([
    [np.pi/10.],
    [0.]
])
u = []
x = []
x.append(x_0)
for k in range(0, N_sim):
    u.append(controller.feedback(x[k]))
    x.append(sys.A.dot(x[k]) + sys.B.dot(u[k]))
x = sys.simulate(x_0, N_sim, u)

# %% [markdown]
# We can plot the solution using the functions $\texttt{plot_input_sequence(.)}$ and $\texttt{plot_state_trajectory(.)}$

# %%
mpc.plot_input_sequence(u, t_s, N_sim, u_max, u_min)
plt.show()
mpc.plot_state_trajectory(x, t_s, N_sim, x_max, x_min)
plt.show()

# %% [markdown]
# We can get the explict solution of the optimal control problem and plot the consequent state partition.

# %%
controller.compute_explicit_solution()
# Out:
# Computing critical region for the active set []
# Computing critical region for the active set [0]
# Computing critical region for the active set [1]
# Computing critical region for the active set [10]
# Computing critical region for the active set [11]
# Computing critical region for the active set [12]
# Computing critical region for the active set [13]
# Computing critical region for the active set [14]
# Computing critical region for the active set [15]
# Computing critical region for the active set [0, 2]
# LICQ does not hold for the active set [0, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 14]
# Computing critical region for the active set [0, 16]
# Computing critical region for the active set [1, 3]
# LICQ does not hold for the active set [1, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 15]
# Computing critical region for the active set [1, 17]
# Computing critical region for the active set [10, 12]
# Computing critical region for the active set [11, 13]
# Computing critical region for the active set [12, 14]
# Computing critical region for the active set [13, 15]
# Computing critical region for the active set [0, 2, 4]
# LICQ does not hold for the active set [0, 2, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 16]
# Computing critical region for the active set [0, 2, 18]
# Computing critical region for the active set [0, 12, 14]
# Computing critical region for the active set [0, 14, 16]
# Computing critical region for the active set [1, 3, 5]
# LICQ does not hold for the active set [1, 3, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 17]
# Computing critical region for the active set [1, 3, 19]
# Computing critical region for the active set [1, 13, 15]
# Computing critical region for the active set [1, 15, 17]
# LICQ does not hold for the active set [1, 10, 12]
#     unfeasible critical region detected
# Computing critical region for the active set [10, 12, 14]
# LICQ does not hold for the active set [0, 11, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [11, 13, 15]
# Computing critical region for the active set [12, 14, 16]
# Computing critical region for the active set [13, 15, 17]
# Computing critical region for the active set [0, 2, 4, 6]
# LICQ does not hold for the active set [0, 2, 4, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 4, 18]
# Computing critical region for the active set [0, 2, 4, 22]
# Computing critical region for the active set [0, 2, 14, 16]
# Computing critical region for the active set [0, 2, 16, 18]
# Computing critical region for the active set [0, 12, 14, 16]
# Computing critical region for the active set [0, 14, 16, 18]
# Computing critical region for the active set [1, 3, 5, 7]
# LICQ does not hold for the active set [1, 3, 5, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 5, 19]
# Computing critical region for the active set [1, 3, 5, 23]
# Computing critical region for the active set [1, 3, 15, 17]
# Computing critical region for the active set [1, 3, 17, 19]
# Computing critical region for the active set [1, 13, 15, 17]
# Computing critical region for the active set [1, 15, 17, 19]
# LICQ does not hold for the active set [1, 10, 12, 14]
#     unfeasible critical region detected
# Computing critical region for the active set [10, 12, 14, 16]
# LICQ does not hold for the active set [0, 11, 13, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [11, 13, 15, 17]
# Computing critical region for the active set [0, 2, 4, 6, 8]
# LICQ does not hold for the active set [0, 2, 4, 6, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 4, 6, 22]
# Computing critical region for the active set [0, 2, 4, 6, 24]
# Computing critical region for the active set [0, 2, 4, 16, 18]
# Computing critical region for the active set [0, 2, 4, 18, 22]
# Computing critical region for the active set [0, 2, 4, 16, 22]
# Computing critical region for the active set [0, 2, 4, 22, 24]
# Computing critical region for the active set [0, 2, 14, 16, 18]
# Computing critical region for the active set [0, 2, 16, 18, 22]
# LICQ does not hold for the active set [0, 10, 12, 14, 16]
#     corrected active set [10, 12, 14, 16]
# Computing critical region for the active set [10, 12, 14, 16]
# Computing critical region for the active set [0, 12, 14, 16, 18]
# Computing critical region for the active set [1, 3, 5, 7, 9]
# LICQ does not hold for the active set [1, 3, 5, 7, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 5, 7, 23]
# Computing critical region for the active set [1, 3, 5, 7, 25]
# Computing critical region for the active set [1, 3, 5, 17, 19]
# Computing critical region for the active set [1, 3, 5, 19, 23]
# Computing critical region for the active set [1, 3, 5, 17, 23]
# Computing critical region for the active set [1, 3, 5, 23, 25]
# Computing critical region for the active set [1, 3, 15, 17, 19]
# Computing critical region for the active set [1, 3, 17, 19, 23]
# LICQ does not hold for the active set [1, 11, 13, 15, 17]
#     corrected active set [11, 13, 15, 17]
# Computing critical region for the active set [11, 13, 15, 17]
# Computing critical region for the active set [1, 13, 15, 17, 19]
# LICQ does not hold for the active set [1, 10, 12, 14, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [10, 12, 14, 16, 18]
# LICQ does not hold for the active set [0, 11, 13, 15, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [11, 13, 15, 17, 19]
# LICQ does not hold for the active set [0, 2, 4, 6, 8, 11]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 6, 8, 24]
#     corrected active set [0, 2, 4, 6, 24]
# Computing critical region for the active set [0, 2, 4, 6, 24]
# LICQ does not hold for the active set [0, 2, 4, 6, 22, 24]
#     corrected active set [0, 2, 4, 6, 24]
# Computing critical region for the active set [0, 2, 4, 6, 24]
# LICQ does not hold for the active set [0, 2, 4, 6, 11, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 6, 16, 24]
#     corrected active set [0, 2, 4, 16, 24]
# Computing critical region for the active set [0, 2, 4, 16, 24]
# LICQ does not hold for the active set [0, 2, 4, 6, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 16, 18, 22]
#     corrected active set [0, 2, 4, 16, 22]
# Computing critical region for the active set [0, 2, 4, 16, 22]
# Computing critical region for the active set [0, 2, 16, 22]
# LICQ does not hold for the active set [0, 2, 4, 14, 16, 22]
#     corrected active set [0, 2, 14, 16, 22]
# Computing critical region for the active set [0, 2, 14, 16, 22]
# LICQ does not hold for the active set [0, 2, 4, 16, 22, 24]
#     corrected active set [0, 2, 4, 16, 24]
# Computing critical region for the active set [0, 2, 4, 16, 24]
# LICQ does not hold for the active set [0, 2, 12, 14, 16, 18]
#     corrected active set [0, 12, 14, 16, 18]
# Computing critical region for the active set [0, 12, 14, 16, 18]
# LICQ does not hold for the active set [0, 2, 14, 16, 18, 22]
#     corrected active set [0, 2, 14, 16, 22]
# Computing critical region for the active set [0, 2, 14, 16, 22]
# LICQ does not hold for the active set [0, 10, 12, 14, 16, 18]
#     corrected active set [10, 12, 14, 16, 18]
# Computing critical region for the active set [10, 12, 14, 16, 18]
# LICQ does not hold for the active set [0, 12, 14, 16, 18, 22]
#     corrected active set [0, 12, 14, 16, 22]
# Computing critical region for the active set [0, 12, 14, 16, 22]
# LICQ does not hold for the active set [1, 3, 5, 7, 9, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 7, 9, 25]
#     corrected active set [1, 3, 5, 7, 25]
# Computing critical region for the active set [1, 3, 5, 7, 25]
# LICQ does not hold for the active set [1, 3, 5, 7, 23, 25]
#     corrected active set [1, 3, 5, 7, 25]
# Computing critical region for the active set [1, 3, 5, 7, 25]
# LICQ does not hold for the active set [1, 3, 5, 7, 10, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 7, 17, 25]
#     corrected active set [1, 3, 5, 17, 25]
# Computing critical region for the active set [1, 3, 5, 17, 25]
# LICQ does not hold for the active set [1, 3, 5, 7, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 17, 19, 23]
#     corrected active set [1, 3, 5, 17, 23]
# Computing critical region for the active set [1, 3, 5, 17, 23]
# Computing critical region for the active set [1, 3, 17, 23]
# LICQ does not hold for the active set [1, 3, 5, 15, 17, 23]
#     corrected active set [1, 3, 15, 17, 23]
# Computing critical region for the active set [1, 3, 15, 17, 23]
# LICQ does not hold for the active set [1, 3, 5, 17, 23, 25]
#     corrected active set [1, 3, 5, 17, 25]
# Computing critical region for the active set [1, 3, 5, 17, 25]
# LICQ does not hold for the active set [1, 3, 13, 15, 17, 19]
#     corrected active set [1, 13, 15, 17, 19]
# Computing critical region for the active set [1, 13, 15, 17, 19]
# LICQ does not hold for the active set [1, 3, 15, 17, 19, 23]
#     corrected active set [1, 3, 15, 17, 23]
# Computing critical region for the active set [1, 3, 15, 17, 23]
# LICQ does not hold for the active set [1, 11, 13, 15, 17, 19]
#     corrected active set [11, 13, 15, 17, 19]
# Computing critical region for the active set [11, 13, 15, 17, 19]
# LICQ does not hold for the active set [1, 13, 15, 17, 19, 23]
#     corrected active set [1, 13, 15, 17, 23]
# Computing critical region for the active set [1, 13, 15, 17, 23]
# LICQ does not hold for the active set [1, 10, 12, 14, 16, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 12, 14, 16, 18, 22]
#     corrected active set [10, 12, 14, 16, 22]
# Computing critical region for the active set [10, 12, 14, 16, 22]
# LICQ does not hold for the active set [0, 11, 13, 15, 17, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 13, 15, 17, 19, 23]
#     corrected active set [11, 13, 15, 17, 23]
# Computing critical region for the active set [11, 13, 15, 17, 23]
# LICQ does not hold for the active set [0, 2, 4, 14, 16, 24]
#     corrected active set [0, 2, 14, 16, 24]
# Computing critical region for the active set [0, 2, 14, 16, 24]
# LICQ does not hold for the active set [0, 2, 4, 16, 24, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 14, 16, 22]
# LICQ does not hold for the active set [0, 2, 12, 14, 16, 22]
#     corrected active set [0, 12, 14, 16, 22]
# Computing critical region for the active set [0, 12, 14, 16, 22]
# LICQ does not hold for the active set [0, 2, 14, 16, 22, 24]
#     corrected active set [0, 2, 14, 16, 24]
# Computing critical region for the active set [0, 2, 14, 16, 24]
# LICQ does not hold for the active set [0, 10, 12, 14, 16, 22]
#     corrected active set [10, 12, 14, 16, 22]
# Computing critical region for the active set [10, 12, 14, 16, 22]
# LICQ does not hold for the active set [0, 12, 14, 16, 22, 24]
#     corrected active set [0, 12, 14, 16, 24]
# Computing critical region for the active set [0, 12, 14, 16, 24]
# LICQ does not hold for the active set [1, 3, 5, 15, 17, 25]
#     corrected active set [1, 3, 15, 17, 25]
# Computing critical region for the active set [1, 3, 15, 17, 25]
# LICQ does not hold for the active set [1, 3, 5, 17, 25, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 15, 17, 23]
# LICQ does not hold for the active set [1, 3, 13, 15, 17, 23]
#     corrected active set [1, 13, 15, 17, 23]
# Computing critical region for the active set [1, 13, 15, 17, 23]
# LICQ does not hold for the active set [1, 3, 15, 17, 23, 25]
#     corrected active set [1, 3, 15, 17, 25]
# Computing critical region for the active set [1, 3, 15, 17, 25]
# LICQ does not hold for the active set [1, 11, 13, 15, 17, 23]
#     corrected active set [11, 13, 15, 17, 23]
# Computing critical region for the active set [11, 13, 15, 17, 23]
# LICQ does not hold for the active set [1, 13, 15, 17, 23, 25]
#     corrected active set [1, 13, 15, 17, 25]
# Computing critical region for the active set [1, 13, 15, 17, 25]
# LICQ does not hold for the active set [1, 10, 12, 14, 16, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 12, 14, 16, 22, 24]
#     corrected active set [10, 12, 14, 16, 24]
# Computing critical region for the active set [10, 12, 14, 16, 24]
# LICQ does not hold for the active set [0, 11, 13, 15, 17, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 13, 15, 17, 23, 25]
#     corrected active set [11, 13, 15, 17, 25]
# Computing critical region for the active set [11, 13, 15, 17, 25]
# LICQ does not hold for the active set [0, 2, 12, 14, 16, 24]
#     corrected active set [0, 12, 14, 16, 24]
# Computing critical region for the active set [0, 12, 14, 16, 24]
# LICQ does not hold for the active set [0, 2, 14, 16, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 12, 14, 16, 24]
#     corrected active set [10, 12, 14, 16, 24]
# Computing critical region for the active set [10, 12, 14, 16, 24]
# LICQ does not hold for the active set [0, 12, 14, 16, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 13, 15, 17, 25]
#     corrected active set [1, 13, 15, 17, 25]
# Computing critical region for the active set [1, 13, 15, 17, 25]
# LICQ does not hold for the active set [1, 3, 15, 17, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 13, 15, 17, 25]
#     corrected active set [11, 13, 15, 17, 25]
# Computing critical region for the active set [11, 13, 15, 17, 25]
# LICQ does not hold for the active set [1, 13, 15, 17, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 12, 14, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 12, 14, 16, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 13, 15, 17, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 13, 15, 17, 25, 27]
#     unfeasible critical region detected
#
# Explicit solution successfully computed in 1.396332 s:
# parameter space partitioned in 115 critical regions.

# %%
for cr in controller.critical_regions:
    cr.polytope.plot()
plt.show()

# %% [markdown]
# The result from the explicit solution and the optimal control problem is, of course, the same: let's take $x_0$ for example.

# %%
u_explicit = controller.feedforward_explicit(x_0)
u_implicit = controller.feedforward(x_0)
print('Optimal control from the explicit solution: ' + str(u_explicit.flatten()))
print('Optimal control from the implicit solution: ' + str(u_implicit.flatten()))
# Out:
# Optimal control from the explicit solution: [-3.92699082 -3.92699082 -3.92699082 -3.03454996 -2.28951515]
# Optimal control from the implicit solution: [-3.92699082 -3.92699082 -3.92699082 -3.03454995 -2.28951516]

# %% [markdown]
# ## Cart Pole

# %% [markdown]
# We now place the pendulum over a cart with mass $M$, the new input is the force applied to the cart.

# %%
M = 1.

# %% [markdown]
# The linearized dynamics becomes
# \begin{equation}
# \dot x =
# \begin{bmatrix}
# 0 & 0 & 0 & 1
# \\
# 0 & 0 & 0 & 1
# \\
# 0 & -mg/M & 0 & 0
# \\
# 0 & -(M+m)g/(Ml) & 0 & 0
# \end{bmatrix}
# x +
# \begin{bmatrix}
# 0
# \\
# 0
# \\
# 1/M
# \\
# 1/(Ml)
# \end{bmatrix}
# u.
# \end{equation}

# %%
A = np.array([
    [0., 0., 1., 0.,],
    [0., 0., 0., 1.,],
    [0., -m*g/M, 0., 0.,],
    [0., (M+m)*g/(l*M), 0., 0.,]
])
B = np.array([
    [0.],
    [0.], 
    [1./M], 
    [1./(l*M)]
])
sys = mpc.DTLinearSystem.from_continuous(t_s, A, B)

# %% [markdown]
# In this case we use a shorter horizon $N$ in order to have a compact optimization problem.

# %%
N = 2
terminal_constraint = 'moas'

# %% [markdown]
# The new parameters are the following.

# %%
x_max = np.array([
    [3.],
    [np.pi/6.],
    [4.],
    [np.pi/15./(N*t_s)]
])
x_min = -x_max
u_max = np.array([[10.]])
u_min = -u_max
Q = np.eye(A.shape[0])
R = np.eye(B.shape[1])
x_0 = np.array([
    [0.],
    [np.pi/10.],
    [0.],
    [0.]
])*0.

# %% [markdown]
# We can now assemble the controller for the new system.

# %%
factory = mqp.MPCQPFactory(sys, N, Q, R, terminal_cost)
factory.add_state_bound(x_max, x_min)
factory.add_input_bound(u_max, u_min)
factory.set_terminal_constraint(terminal_constraint)
qp = factory.assemble()
controller = mpc.MPCController(qp, sys.n_u)

# %% [markdown]
# We simulate the closed loop system.

# %%
u = []
x = []
x.append(x_0)
for k in range(0, N_sim):
    u.append(controller.feedback(x[k]))
    x.append(sys.A.dot(x[k]) + sys.B.dot(u[k]))
mpc.plot_input_sequence(u, t_s, N_sim, u_max, u_min)
plt.ylim(-11, 11)
plt.show()
mpc.plot_state_trajectory(x, t_s, N_sim, x_max, x_min)
plt.show()

# %% [markdown]
# In this case the explicit solution might take much more time. The state space has now 4 dimensions, but we can still plot the 2D projections of the critical regions.

# %%
controller.compute_explicit_solution()
# Out:
# Computing critical region for the active set []
# Computing critical region for the active set [0]
# Computing critical region for the active set [1]
# Computing critical region for the active set [4]
# Computing critical region for the active set [6]
# Computing critical region for the active set [7]
# Computing critical region for the active set [8]
# Computing critical region for the active set [10]
# Computing critical region for the active set [11]
# Computing critical region for the active set [12]
# Computing critical region for the active set [13]
# Computing critical region for the active set [14]
# Computing critical region for the active set [15]
# Computing critical region for the active set [16]
# Computing critical region for the active set [17]
# Computing critical region for the active set [20]
# Computing critical region for the active set [21]
# Computing critical region for the active set [23]
# Computing critical region for the active set [24]
# Computing critical region for the active set [26]
# Computing critical region for the active set [29]
# Computing critical region for the active set [32]
# Computing critical region for the active set [34]
# Computing critical region for the active set [36]
# Computing critical region for the active set [37]
# Computing critical region for the active set [38]
# Computing critical region for the active set [39]
# Computing critical region for the active set [40]
# Computing critical region for the active set [41]
# Computing critical region for the active set [42]
# Computing critical region for the active set [43]
# Computing critical region for the active set [44]
# Computing critical region for the active set [45]
# Computing critical region for the active set [0, 2]
# LICQ does not hold for the active set [0, 4]
#     corrected active set [4]
# Computing critical region for the active set [4]
# LICQ does not hold for the active set [0, 7]
#     corrected active set [0, 7]
# Computing critical region for the active set [0, 7]
# LICQ does not hold for the active set [0, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 13]
# Computing critical region for the active set [0, 14]
# Computing critical region for the active set [0, 15]
# Computing critical region for the active set [0, 21]
# Computing critical region for the active set [0, 22]
# Computing critical region for the active set [0, 23]
# Computing critical region for the active set [0, 26]
# Computing critical region for the active set [0, 27]
# Computing critical region for the active set [0, 29]
# Computing critical region for the active set [0, 32]
# Computing critical region for the active set [0, 34]
# Computing critical region for the active set [0, 36]
# Computing critical region for the active set [0, 37]
# Computing critical region for the active set [0, 38]
# Computing critical region for the active set [0, 39]
# Computing critical region for the active set [0, 40]
# Computing critical region for the active set [0, 42]
# Computing critical region for the active set [0, 44]
# Computing critical region for the active set [0, 46]
# Computing critical region for the active set [1, 3]
# LICQ does not hold for the active set [1, 4]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8]
#     corrected active set [8]
# Computing critical region for the active set [8]
# LICQ does not hold for the active set [1, 11]
#     corrected active set [11]
# Computing critical region for the active set [11]
# Computing critical region for the active set [1, 12]
# Computing critical region for the active set [1, 16]
# Computing critical region for the active set [1, 17]
# Computing critical region for the active set [1, 20]
# Computing critical region for the active set [1, 24]
# Computing critical region for the active set [1, 25]
# Computing critical region for the active set [1, 26]
# Computing critical region for the active set [1, 29]
# Computing critical region for the active set [1, 30]
# Computing critical region for the active set [1, 32]
# Computing critical region for the active set [1, 34]
# Computing critical region for the active set [1, 36]
# Computing critical region for the active set [1, 37]
# Computing critical region for the active set [1, 38]
# Computing critical region for the active set [1, 39]
# Computing critical region for the active set [1, 41]
# Computing critical region for the active set [1, 43]
# Computing critical region for the active set [1, 45]
# Computing critical region for the active set [1, 47]
# Computing critical region for the active set [2, 4]
# LICQ does not hold for the active set [4, 7]
#     corrected active set [4, 7]
# Computing critical region for the active set [4, 7]
# LICQ does not hold for the active set [4, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [4, 12]
# Computing critical region for the active set [4, 14]
# Computing critical region for the active set [4, 16]
# Computing critical region for the active set [4, 20]
# Computing critical region for the active set [4, 24]
# Computing critical region for the active set [4, 26]
# Computing critical region for the active set [4, 32]
# Computing critical region for the active set [4, 36]
# Computing critical region for the active set [4, 38]
# LICQ does not hold for the active set [6, 7]
#     corrected active set [7]
# Computing critical region for the active set [7]
# LICQ does not hold for the active set [6, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 13]
# Computing critical region for the active set [6, 36]
# Computing critical region for the active set [6, 38]
# Computing critical region for the active set [6, 40]
# Computing critical region for the active set [6, 42]
# Computing critical region for the active set [6, 44]
# LICQ does not hold for the active set [7, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [7, 12]
# Computing critical region for the active set [7, 13]
# Computing critical region for the active set [7, 14]
# Computing critical region for the active set [7, 15]
# Computing critical region for the active set [7, 16]
# Computing critical region for the active set [7, 20]
# Computing critical region for the active set [7, 21]
# Computing critical region for the active set [7, 23]
# Computing critical region for the active set [7, 26]
# Computing critical region for the active set [7, 29]
# Computing critical region for the active set [7, 32]
# Computing critical region for the active set [7, 34]
# Computing critical region for the active set [7, 36]
# Computing critical region for the active set [7, 37]
# Computing critical region for the active set [7, 38]
# Computing critical region for the active set [7, 39]
# Computing critical region for the active set [7, 40]
# Computing critical region for the active set [7, 41]
# Computing critical region for the active set [7, 42]
# Computing critical region for the active set [7, 43]
# Computing critical region for the active set [7, 44]
# Computing critical region for the active set [7, 45]
# Computing critical region for the active set [3, 8]
# LICQ does not hold for the active set [8, 11]
#     corrected active set [8, 11]
# Computing critical region for the active set [8, 11]
# Computing critical region for the active set [8, 13]
# Computing critical region for the active set [8, 15]
# Computing critical region for the active set [8, 17]
# Computing critical region for the active set [8, 21]
# Computing critical region for the active set [8, 23]
# Computing critical region for the active set [8, 29]
# Computing critical region for the active set [8, 34]
# Computing critical region for the active set [8, 37]
# Computing critical region for the active set [8, 39]
# LICQ does not hold for the active set [10, 11]
#     corrected active set [11]
# Computing critical region for the active set [11]
# Computing critical region for the active set [10, 16]
# Computing critical region for the active set [10, 37]
# Computing critical region for the active set [10, 39]
# Computing critical region for the active set [10, 41]
# Computing critical region for the active set [10, 43]
# Computing critical region for the active set [10, 45]
# LICQ does not hold for the active set [5, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [11, 12]
# Computing critical region for the active set [11, 13]
# Computing critical region for the active set [11, 15]
# Computing critical region for the active set [11, 16]
# Computing critical region for the active set [11, 17]
# Computing critical region for the active set [11, 20]
# Computing critical region for the active set [11, 23]
# Computing critical region for the active set [11, 24]
# Computing critical region for the active set [11, 26]
# Computing critical region for the active set [11, 29]
# Computing critical region for the active set [11, 32]
# Computing critical region for the active set [11, 34]
# Computing critical region for the active set [11, 36]
# Computing critical region for the active set [11, 37]
# Computing critical region for the active set [11, 38]
# Computing critical region for the active set [11, 39]
# Computing critical region for the active set [11, 40]
# Computing critical region for the active set [11, 41]
# Computing critical region for the active set [11, 42]
# Computing critical region for the active set [11, 43]
# Computing critical region for the active set [11, 44]
# Computing critical region for the active set [11, 45]
# Computing critical region for the active set [12, 20]
# Computing critical region for the active set [12, 26]
# Computing critical region for the active set [13, 14]
# Computing critical region for the active set [13, 21]
# Computing critical region for the active set [13, 42]
# Computing critical region for the active set [13, 44]
# Computing critical region for the active set [13, 46]
# Computing critical region for the active set [14, 44]
# Computing critical region for the active set [15, 23]
# Computing critical region for the active set [15, 29]
# Computing critical region for the active set [16, 17]
# Computing critical region for the active set [16, 24]
# Computing critical region for the active set [16, 43]
# Computing critical region for the active set [16, 45]
# Computing critical region for the active set [16, 47]
# Computing critical region for the active set [17, 45]
# Computing critical region for the active set [17, 20]
# Computing critical region for the active set [20, 26]
# Computing critical region for the active set [14, 23]
# Computing critical region for the active set [23, 29]
# Computing critical region for the active set [3, 26]
# Computing critical region for the active set [5, 26]
# Computing critical region for the active set [17, 26]
# Computing critical region for the active set [26, 32]
# Computing critical region for the active set [2, 29]
# Computing critical region for the active set [9, 29]
# Computing critical region for the active set [14, 29]
# Computing critical region for the active set [29, 34]
# Computing critical region for the active set [3, 32]
# Computing critical region for the active set [5, 32]
# Computing critical region for the active set [6, 32]
# Computing critical region for the active set [19, 32]
# Computing critical region for the active set [32, 36]
# Computing critical region for the active set [2, 34]
# Computing critical region for the active set [9, 34]
# Computing critical region for the active set [10, 34]
# Computing critical region for the active set [18, 34]
# Computing critical region for the active set [34, 37]
# Computing critical region for the active set [5, 36]
# Computing critical region for the active set [19, 36]
# Computing critical region for the active set [36, 38]
# Computing critical region for the active set [9, 37]
# Computing critical region for the active set [18, 37]
# Computing critical region for the active set [37, 39]
# Computing critical region for the active set [38, 40]
# Computing critical region for the active set [39, 41]
# Computing critical region for the active set [13, 40]
# Computing critical region for the active set [40, 42]
# Computing critical region for the active set [16, 41]
# Computing critical region for the active set [41, 43]
# Computing critical region for the active set [14, 42]
# Computing critical region for the active set [42, 44]
# Computing critical region for the active set [17, 43]
# Computing critical region for the active set [43, 45]
# LICQ does not hold for the active set [0, 2, 4]
#     corrected active set [2, 4]
# Computing critical region for the active set [2, 4]
# LICQ does not hold for the active set [0, 2, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 11]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 14]
#     corrected active set [0, 14]
# Computing critical region for the active set [0, 14]
# LICQ does not hold for the active set [0, 2, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 22]
#     corrected active set [0, 22]
# Computing critical region for the active set [0, 22]
# LICQ does not hold for the active set [0, 2, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 29]
#     corrected active set [2, 29]
# Computing critical region for the active set [2, 29]
# LICQ does not hold for the active set [0, 2, 33]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 34]
#     corrected active set [2, 34]
# Computing critical region for the active set [2, 34]
# LICQ does not hold for the active set [0, 2, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 37]
#     corrected active set [0, 37]
# Computing critical region for the active set [0, 37]
# LICQ does not hold for the active set [0, 2, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 48]
#     unfeasible critical region detected
# Empty critical region detected
# LICQ does not hold for the active set [0, 6, 13]
#     corrected active set [6, 13]
# Computing critical region for the active set [6, 13]
# LICQ does not hold for the active set [0, 7, 13]
#     corrected active set [7, 13]
# Computing critical region for the active set [7, 13]
# LICQ does not hold for the active set [0, 8, 13]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 13]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 14]
#     corrected active set [0, 14]
# Computing critical region for the active set [0, 14]
# LICQ does not hold for the active set [0, 13, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 14]
#     corrected active set [4, 14]
# Computing critical region for the active set [4, 14]
# LICQ does not hold for the active set [0, 7, 14]
#     corrected active set [7, 14]
# Computing critical region for the active set [7, 14]
# LICQ does not hold for the active set [0, 8, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 22]
#     corrected active set [0, 22]
# Computing critical region for the active set [0, 22]
# LICQ does not hold for the active set [0, 14, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 7, 15]
#     corrected active set [7, 15]
# Computing critical region for the active set [7, 15]
# LICQ does not hold for the active set [0, 8, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 15, 23]
#     corrected active set [0, 23]
# Computing critical region for the active set [0, 23]
# LICQ does not hold for the active set [0, 15, 29]
#     corrected active set [15, 29]
# Computing critical region for the active set [15, 29]
# LICQ does not hold for the active set [0, 15, 34]
#     corrected active set [15, 34]
# Computing critical region for the active set [15, 34]
# LICQ does not hold for the active set [0, 15, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 7, 21]
#     corrected active set [7, 21]
# Computing critical region for the active set [7, 21]
# LICQ does not hold for the active set [0, 8, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 21, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 21, 27]
#     corrected active set [0, 27]
# Computing critical region for the active set [0, 27]
# LICQ does not hold for the active set [0, 21, 44]
#     corrected active set [0, 44]
# Computing critical region for the active set [0, 44]
# LICQ does not hold for the active set [0, 21, 46]
#     corrected active set [0, 46]
# Computing critical region for the active set [0, 46]
# LICQ does not hold for the active set [0, 4, 22]
#     corrected active set [4, 22]
# Computing critical region for the active set [4, 22]
# LICQ does not hold for the active set [0, 7, 22]
#     corrected active set [7, 22]
# Computing critical region for the active set [7, 22]
# LICQ does not hold for the active set [0, 8, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 15, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 18, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 33]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 22, 48]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 7, 23]
#     corrected active set [7, 23]
# Computing critical region for the active set [7, 23]
# LICQ does not hold for the active set [0, 9, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 23, 29]
#     corrected active set [23, 29]
# Computing critical region for the active set [23, 29]
# LICQ does not hold for the active set [0, 3, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 26]
#     corrected active set [4, 26]
# Computing critical region for the active set [4, 26]
# LICQ does not hold for the active set [0, 7, 26]
#     corrected active set [7, 26]
# Computing critical region for the active set [7, 26]
# LICQ does not hold for the active set [0, 11, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 26]
#     corrected active set [12, 26]
# Computing critical region for the active set [12, 26]
# LICQ does not hold for the active set [0, 17, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 20, 26]
#     corrected active set [20, 26]
# Computing critical region for the active set [20, 26]
# LICQ does not hold for the active set [0, 26, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 8, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 7, 29]
#     corrected active set [7, 29]
# Computing critical region for the active set [7, 29]
# LICQ does not hold for the active set [0, 9, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 29]
#     corrected active set [14, 29]
# Computing critical region for the active set [14, 29]
# LICQ does not hold for the active set [0, 29, 34]
#     corrected active set [29, 34]
# Computing critical region for the active set [29, 34]
# LICQ does not hold for the active set [0, 2, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 32]
#     corrected active set [4, 32]
# Computing critical region for the active set [4, 32]
# LICQ does not hold for the active set [0, 5, 32]
#     corrected active set [5, 32]
# Computing critical region for the active set [5, 32]
# LICQ does not hold for the active set [0, 6, 32]
#     corrected active set [6, 32]
# Computing critical region for the active set [6, 32]
# LICQ does not hold for the active set [0, 7, 32]
#     corrected active set [7, 32]
# Computing critical region for the active set [7, 32]
# LICQ does not hold for the active set [0, 11, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 19, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 32, 36]
#     corrected active set [0, 36]
# Computing critical region for the active set [0, 36]
# LICQ does not hold for the active set [0, 7, 34]
#     corrected active set [7, 34]
# Computing critical region for the active set [7, 34]
# LICQ does not hold for the active set [0, 9, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 34, 37]
#     corrected active set [0, 37]
# Computing critical region for the active set [0, 37]
# LICQ does not hold for the active set [0, 4, 36]
#     corrected active set [4, 36]
# Computing critical region for the active set [4, 36]
# LICQ does not hold for the active set [0, 6, 36]
#     corrected active set [6, 36]
# Computing critical region for the active set [6, 36]
# LICQ does not hold for the active set [0, 7, 36]
#     corrected active set [7, 36]
# Computing critical region for the active set [7, 36]
# LICQ does not hold for the active set [0, 11, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 19, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 36, 38]
#     corrected active set [0, 38]
# Computing critical region for the active set [0, 38]
# LICQ does not hold for the active set [0, 7, 37]
#     corrected active set [7, 37]
# Computing critical region for the active set [7, 37]
# LICQ does not hold for the active set [0, 9, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 37, 39]
#     corrected active set [0, 39]
# Computing critical region for the active set [0, 39]
# LICQ does not hold for the active set [0, 4, 38]
#     corrected active set [4, 38]
# Computing critical region for the active set [4, 38]
# LICQ does not hold for the active set [0, 6, 38]
#     corrected active set [6, 38]
# Computing critical region for the active set [6, 38]
# LICQ does not hold for the active set [0, 7, 38]
#     corrected active set [7, 38]
# Computing critical region for the active set [7, 38]
# LICQ does not hold for the active set [0, 11, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 19, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 38, 40]
#     corrected active set [0, 40]
# Computing critical region for the active set [0, 40]
# LICQ does not hold for the active set [0, 10, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 40]
#     corrected active set [6, 40]
# Computing critical region for the active set [6, 40]
# LICQ does not hold for the active set [0, 7, 40]
#     corrected active set [7, 40]
# Computing critical region for the active set [7, 40]
# LICQ does not hold for the active set [0, 11, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 40, 42]
#     corrected active set [0, 42]
# Computing critical region for the active set [0, 42]
# LICQ does not hold for the active set [0, 6, 42]
#     corrected active set [6, 42]
# Computing critical region for the active set [6, 42]
# LICQ does not hold for the active set [0, 7, 42]
#     corrected active set [7, 42]
# Computing critical region for the active set [7, 42]
# LICQ does not hold for the active set [0, 11, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 42, 44]
#     corrected active set [0, 44]
# Computing critical region for the active set [0, 44]
# LICQ does not hold for the active set [0, 7, 44]
#     corrected active set [7, 44]
# Computing critical region for the active set [7, 44]
# LICQ does not hold for the active set [0, 11, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 44, 46]
#     corrected active set [0, 46]
# Computing critical region for the active set [0, 46]
# LICQ does not hold for the active set [0, 11, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 4]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 8]
#     corrected active set [3, 8]
# Computing critical region for the active set [3, 8]
# LICQ does not hold for the active set [1, 3, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 17]
#     corrected active set [1, 17]
# Computing critical region for the active set [1, 17]
# LICQ does not hold for the active set [1, 3, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 25]
#     corrected active set [1, 25]
# Computing critical region for the active set [1, 25]
# LICQ does not hold for the active set [1, 3, 26]
#     corrected active set [3, 26]
# Computing critical region for the active set [3, 26]
# LICQ does not hold for the active set [1, 3, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 31]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 32]
#     corrected active set [3, 32]
# Computing critical region for the active set [3, 32]
# LICQ does not hold for the active set [1, 3, 35]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 36]
#     corrected active set [1, 36]
# Computing critical region for the active set [1, 36]
# LICQ does not hold for the active set [1, 3, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 49]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 12]
#     corrected active set [11, 12]
# Computing critical region for the active set [11, 12]
# LICQ does not hold for the active set [1, 12, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 20]
#     corrected active set [1, 20]
# Computing critical region for the active set [1, 20]
# LICQ does not hold for the active set [1, 12, 26]
#     corrected active set [12, 26]
# Computing critical region for the active set [12, 26]
# LICQ does not hold for the active set [1, 12, 32]
#     corrected active set [12, 32]
# Computing critical region for the active set [12, 32]
# LICQ does not hold for the active set [1, 12, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 16]
#     corrected active set [10, 16]
# Computing critical region for the active set [10, 16]
# LICQ does not hold for the active set [1, 11, 16]
#     corrected active set [11, 16]
# Computing critical region for the active set [11, 16]
# LICQ does not hold for the active set [1, 16, 17]
#     corrected active set [1, 17]
# Computing critical region for the active set [1, 17]
# LICQ does not hold for the active set [1, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 16, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 16, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 17]
#     corrected active set [8, 17]
# Computing critical region for the active set [8, 17]
# LICQ does not hold for the active set [1, 11, 17]
#     corrected active set [11, 17]
# Computing critical region for the active set [11, 17]
# LICQ does not hold for the active set [1, 17, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 25]
#     corrected active set [1, 25]
# Computing critical region for the active set [1, 25]
# LICQ does not hold for the active set [1, 17, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 17, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 20]
#     corrected active set [11, 20]
# Computing critical region for the active set [11, 20]
# LICQ does not hold for the active set [1, 20, 26]
#     corrected active set [20, 26]
# Computing critical region for the active set [20, 26]
# LICQ does not hold for the active set [1, 4, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 24]
#     corrected active set [11, 24]
# Computing critical region for the active set [11, 24]
# LICQ does not hold for the active set [1, 24, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 24, 30]
#     corrected active set [1, 30]
# Computing critical region for the active set [1, 30]
# LICQ does not hold for the active set [1, 24, 45]
#     corrected active set [1, 45]
# Computing critical region for the active set [1, 45]
# LICQ does not hold for the active set [1, 24, 47]
#     corrected active set [1, 47]
# Computing critical region for the active set [1, 47]
# LICQ does not hold for the active set [1, 4, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 25]
#     corrected active set [8, 25]
# Computing critical region for the active set [8, 25]
# LICQ does not hold for the active set [1, 11, 25]
#     corrected active set [11, 25]
# Computing critical region for the active set [11, 25]
# LICQ does not hold for the active set [1, 12, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 19, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 31]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 35]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 25, 49]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 26]
#     corrected active set [11, 26]
# Computing critical region for the active set [11, 26]
# LICQ does not hold for the active set [1, 17, 26]
#     corrected active set [17, 26]
# Computing critical region for the active set [17, 26]
# LICQ does not hold for the active set [1, 26, 32]
#     corrected active set [26, 32]
# Computing critical region for the active set [26, 32]
# LICQ does not hold for the active set [1, 2, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 29]
#     corrected active set [8, 29]
# Computing critical region for the active set [8, 29]
# LICQ does not hold for the active set [1, 11, 29]
#     corrected active set [11, 29]
# Computing critical region for the active set [11, 29]
# LICQ does not hold for the active set [1, 14, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 15, 29]
#     corrected active set [15, 29]
# Computing critical region for the active set [15, 29]
# LICQ does not hold for the active set [1, 23, 29]
#     corrected active set [23, 29]
# Computing critical region for the active set [23, 29]
# LICQ does not hold for the active set [1, 29, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 32]
#     corrected active set [11, 32]
# Computing critical region for the active set [11, 32]
# LICQ does not hold for the active set [1, 32, 36]
#     corrected active set [1, 36]
# Computing critical region for the active set [1, 36]
# LICQ does not hold for the active set [1, 3, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 34]
#     corrected active set [8, 34]
# Computing critical region for the active set [8, 34]
# LICQ does not hold for the active set [1, 9, 34]
#     corrected active set [9, 34]
# Computing critical region for the active set [9, 34]
# LICQ does not hold for the active set [1, 10, 34]
#     corrected active set [10, 34]
# Computing critical region for the active set [10, 34]
# LICQ does not hold for the active set [1, 11, 34]
#     corrected active set [11, 34]
# Computing critical region for the active set [11, 34]
# LICQ does not hold for the active set [1, 17, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 18, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 34, 37]
#     corrected active set [1, 37]
# Computing critical region for the active set [1, 37]
# LICQ does not hold for the active set [1, 5, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 36]
#     corrected active set [11, 36]
# Computing critical region for the active set [11, 36]
# LICQ does not hold for the active set [1, 36, 38]
#     corrected active set [1, 38]
# Computing critical region for the active set [1, 38]
# LICQ does not hold for the active set [1, 7, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 37]
#     corrected active set [8, 37]
# Computing critical region for the active set [8, 37]
# LICQ does not hold for the active set [1, 10, 37]
#     corrected active set [10, 37]
# Computing critical region for the active set [10, 37]
# LICQ does not hold for the active set [1, 11, 37]
#     corrected active set [11, 37]
# Computing critical region for the active set [11, 37]
# LICQ does not hold for the active set [1, 16, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 18, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 37, 39]
#     corrected active set [1, 39]
# Computing critical region for the active set [1, 39]
# LICQ does not hold for the active set [1, 6, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 39]
#     corrected active set [8, 39]
# Computing critical region for the active set [8, 39]
# LICQ does not hold for the active set [1, 10, 39]
#     corrected active set [10, 39]
# Computing critical region for the active set [10, 39]
# LICQ does not hold for the active set [1, 11, 39]
#     corrected active set [11, 39]
# Computing critical region for the active set [11, 39]
# LICQ does not hold for the active set [1, 16, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 18, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 39, 41]
#     corrected active set [1, 41]
# Computing critical region for the active set [1, 41]
# LICQ does not hold for the active set [1, 7, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 41]
#     corrected active set [10, 41]
# Computing critical region for the active set [10, 41]
# LICQ does not hold for the active set [1, 11, 41]
#     corrected active set [11, 41]
# Computing critical region for the active set [11, 41]
# LICQ does not hold for the active set [1, 16, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 41, 43]
#     corrected active set [1, 43]
# Computing critical region for the active set [1, 43]
# LICQ does not hold for the active set [1, 7, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 43]
#     corrected active set [10, 43]
# Computing critical region for the active set [10, 43]
# LICQ does not hold for the active set [1, 11, 43]
#     corrected active set [11, 43]
# Computing critical region for the active set [11, 43]
# LICQ does not hold for the active set [1, 16, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 43, 45]
#     corrected active set [1, 45]
# Computing critical region for the active set [1, 45]
# LICQ does not hold for the active set [1, 7, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 11, 45]
#     corrected active set [11, 45]
# Computing critical region for the active set [11, 45]
# LICQ does not hold for the active set [1, 45, 47]
#     corrected active set [1, 47]
# Computing critical region for the active set [1, 47]
# LICQ does not hold for the active set [1, 7, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 4]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 11]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 14]
#     corrected active set [4, 14]
# Computing critical region for the active set [4, 14]
# LICQ does not hold for the active set [2, 4, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 22]
#     corrected active set [4, 22]
# Computing critical region for the active set [4, 22]
# LICQ does not hold for the active set [2, 4, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 42]
#     unfeasible critical region detected
# Empty critical region detected
# LICQ does not hold for the active set [4, 7, 12]
#     corrected active set [7, 12]
# Computing critical region for the active set [7, 12]
# LICQ does not hold for the active set [4, 11, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 12, 20]
#     corrected active set [4, 20]
# Computing critical region for the active set [4, 20]
# LICQ does not hold for the active set [4, 12, 26]
#     corrected active set [4, 26]
# Computing critical region for the active set [4, 26]
# LICQ does not hold for the active set [1, 4, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 7, 14]
#     corrected active set [7, 14]
# Computing critical region for the active set [7, 14]
# LICQ does not hold for the active set [4, 10, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 14, 22]
#     corrected active set [4, 22]
# Computing critical region for the active set [4, 22]
# LICQ does not hold for the active set [4, 14, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 14, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 7, 16]
#     corrected active set [7, 16]
# Computing critical region for the active set [7, 16]
# LICQ does not hold for the active set [4, 10, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 11, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 16, 24]
#     corrected active set [16, 24]
# Computing critical region for the active set [16, 24]
# LICQ does not hold for the active set [1, 4, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 7, 20]
#     corrected active set [7, 20]
# Computing critical region for the active set [7, 20]
# LICQ does not hold for the active set [4, 11, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 20, 26]
#     corrected active set [4, 26]
# Computing critical region for the active set [4, 26]
# LICQ does not hold for the active set [4, 11, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 7, 26]
#     corrected active set [7, 26]
# Computing critical region for the active set [7, 26]
# LICQ does not hold for the active set [4, 11, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 26, 32]
# ...
# Computing critical region for the active set [2, 34]
# LICQ does not hold for the active set [10, 11, 34]
#     corrected active set [10, 34]
# Computing critical region for the active set [10, 34]
# LICQ does not hold for the active set [11, 17, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 18, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 34, 37]
#     corrected active set [11, 37]
# Computing critical region for the active set [11, 37]
# LICQ does not hold for the active set [5, 11, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 36, 38]
#     corrected active set [11, 38]
# Computing critical region for the active set [11, 38]
# LICQ does not hold for the active set [11, 18, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 37, 39]
#     corrected active set [11, 39]
# Computing critical region for the active set [11, 39]
# LICQ does not hold for the active set [11, 38, 40]
#     corrected active set [11, 40]
# Computing critical region for the active set [11, 40]
# LICQ does not hold for the active set [11, 18, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 39, 41]
#     corrected active set [11, 41]
# Computing critical region for the active set [11, 41]
# LICQ does not hold for the active set [11, 40, 42]
#     corrected active set [11, 42]
# Computing critical region for the active set [11, 42]
# LICQ does not hold for the active set [0, 11, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 16, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 41, 43]
#     corrected active set [11, 43]
# Computing critical region for the active set [11, 43]
# LICQ does not hold for the active set [11, 13, 42]
#     corrected active set [13, 42]
# Computing critical region for the active set [13, 42]
# LICQ does not hold for the active set [11, 42, 44]
#     corrected active set [11, 44]
# Computing critical region for the active set [11, 44]
# LICQ does not hold for the active set [0, 11, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 43, 45]
#     corrected active set [11, 45]
# Computing critical region for the active set [11, 45]
# LICQ does not hold for the active set [0, 11, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 17, 20]
#     corrected active set [17, 20]
# Computing critical region for the active set [17, 20]
# LICQ does not hold for the active set [12, 20, 26]
#     corrected active set [12, 26]
# Computing critical region for the active set [12, 26]
# LICQ does not hold for the active set [3, 12, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 17, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 26, 32]
#     corrected active set [12, 32]
# Computing critical region for the active set [12, 32]
# LICQ does not hold for the active set [13, 14, 44]
#     corrected active set [14, 44]
# Computing critical region for the active set [14, 44]
# LICQ does not hold for the active set [13, 21, 44]
#     corrected active set [13, 44]
# Computing critical region for the active set [13, 44]
# LICQ does not hold for the active set [13, 21, 46]
#     corrected active set [13, 46]
# Computing critical region for the active set [13, 46]
# LICQ does not hold for the active set [13, 14, 42]
#     corrected active set [14, 42]
# Computing critical region for the active set [14, 42]
# LICQ does not hold for the active set [13, 40, 42]
#     corrected active set [13, 40]
# Computing critical region for the active set [13, 40]
# LICQ does not hold for the active set [13, 42, 44]
#     corrected active set [13, 44]
# Computing critical region for the active set [13, 44]
# LICQ does not hold for the active set [13, 44, 46]
#     corrected active set [13, 46]
# Computing critical region for the active set [13, 46]
# LICQ does not hold for the active set [14, 42, 44]
#     corrected active set [14, 42]
# Computing critical region for the active set [14, 42]
# LICQ does not hold for the active set [14, 15, 23]
#     corrected active set [14, 23]
# Computing critical region for the active set [14, 23]
# LICQ does not hold for the active set [15, 23, 29]
#     corrected active set [15, 29]
# Computing critical region for the active set [15, 29]
# LICQ does not hold for the active set [2, 15, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [14, 15, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [15, 29, 34]
#     corrected active set [15, 34]
# Computing critical region for the active set [15, 34]
# LICQ does not hold for the active set [16, 17, 45]
#     corrected active set [17, 45]
# Computing critical region for the active set [17, 45]
# LICQ does not hold for the active set [16, 24, 45]
#     corrected active set [16, 45]
# Computing critical region for the active set [16, 45]
# LICQ does not hold for the active set [16, 24, 47]
#     corrected active set [16, 47]
# Computing critical region for the active set [16, 47]
# LICQ does not hold for the active set [16, 17, 43]
#     corrected active set [17, 43]
# Computing critical region for the active set [17, 43]
# LICQ does not hold for the active set [16, 41, 43]
#     corrected active set [16, 41]
# Computing critical region for the active set [16, 41]
# LICQ does not hold for the active set [16, 43, 45]
#     corrected active set [16, 45]
# Computing critical region for the active set [16, 45]
# LICQ does not hold for the active set [16, 45, 47]
#     corrected active set [16, 47]
# Computing critical region for the active set [16, 47]
# LICQ does not hold for the active set [17, 43, 45]
#     corrected active set [17, 43]
# Computing critical region for the active set [17, 43]
# LICQ does not hold for the active set [17, 20, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 20, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [14, 23, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 23, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 5, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 6, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 17, 26]
#     corrected active set [17, 26]
# Computing critical region for the active set [17, 26]
# LICQ does not hold for the active set [3, 19, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 26, 32]
#     corrected active set [26, 32]
# Computing critical region for the active set [26, 32]
# LICQ does not hold for the active set [5, 17, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 26, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [17, 26, 32]
#     corrected active set [26, 32]
# Computing critical region for the active set [26, 32]
# LICQ does not hold for the active set [6, 26, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [19, 26, 32]
#     corrected active set [19, 32]
# Computing critical region for the active set [19, 32]
# LICQ does not hold for the active set [2, 9, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 10, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 14, 29]
#     corrected active set [14, 29]
# Computing critical region for the active set [14, 29]
# LICQ does not hold for the active set [2, 18, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 29, 34]
#     corrected active set [29, 34]
# Computing critical region for the active set [29, 34]
# LICQ does not hold for the active set [9, 14, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 29, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [14, 29, 34]
#     corrected active set [29, 34]
# Computing critical region for the active set [29, 34]
# LICQ does not hold for the active set [10, 29, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [18, 29, 34]
#     corrected active set [18, 34]
# Computing critical region for the active set [18, 34]
# LICQ does not hold for the active set [3, 5, 32]
#     corrected active set [5, 32]
# Computing critical region for the active set [5, 32]
# LICQ does not hold for the active set [3, 6, 32]
#     corrected active set [6, 32]
# Computing critical region for the active set [6, 32]
# LICQ does not hold for the active set [3, 19, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 6, 32]
#     corrected active set [6, 32]
# Computing critical region for the active set [6, 32]
# LICQ does not hold for the active set [5, 19, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 32, 36]
#     corrected active set [32, 36]
# Computing critical region for the active set [32, 36]
# LICQ does not hold for the active set [6, 19, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [19, 32, 36]
#     corrected active set [19, 36]
# Computing critical region for the active set [19, 36]
# LICQ does not hold for the active set [2, 9, 34]
#     corrected active set [9, 34]
# Computing critical region for the active set [9, 34]
# LICQ does not hold for the active set [2, 10, 34]
#     corrected active set [10, 34]
# Computing critical region for the active set [10, 34]
# LICQ does not hold for the active set [2, 18, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 34]
#     corrected active set [10, 34]
# Computing critical region for the active set [10, 34]
# LICQ does not hold for the active set [9, 18, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 34, 37]
#     corrected active set [34, 37]
# Computing critical region for the active set [34, 37]
# LICQ does not hold for the active set [10, 18, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [18, 34, 37]
#     corrected active set [18, 37]
# Computing critical region for the active set [18, 37]
# LICQ does not hold for the active set [14, 40, 42]
#     corrected active set [14, 42]
# Computing critical region for the active set [14, 42]
# LICQ does not hold for the active set [17, 41, 43]
#     corrected active set [17, 43]
# Computing critical region for the active set [17, 43]
# LICQ does not hold for the active set [1, 15, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 15, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 15, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 15, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [14, 15, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [15, 34, 37]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 4, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 7, 22]
#     corrected active set [7, 22]
# Computing critical region for the active set [7, 22]
# LICQ does not hold for the active set [4, 10, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 18, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 22, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 22, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 22, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 8, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 9, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 10, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 15, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 18, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 21, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 33]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 40]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 44]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 46]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 22, 48]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 12, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 12, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 12, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 17, 32]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 32, 36]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 8, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 8, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 11, 25]
#     corrected active set [11, 25]
# Computing critical region for the active set [11, 25]
# LICQ does not hold for the active set [8, 19, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 25, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 25, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 25, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 11, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 11, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 11, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 12, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 19, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 24, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 31]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 35]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 41]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 43]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 45]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 47]
#     unfeasible critical region detected
# LICQ does not hold for the active set [11, 25, 49]
#     unfeasible critical region detected
#
# Explicit solution successfully computed in 14.305172 s:
# parameter space partitioned in 470 critical regions.

# %% [markdown]
# projections = [[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]
# for prj in projections:
#     for cr in controller.critical_regions:
#         cr.polytope.plot(prj)
#     plt.show()

# %% [markdown]
# We finally check that the explicit solution is correct.

# %%
u_explicit = controller.feedforward_explicit(x_0)
u_implicit = controller.feedforward(x_0)
print('Optimal control from the explicit solution: ' + str(u_explicit.flatten()))
print('Optimal control from the implicit solution: ' + str(u_implicit.flatten()))
# Out:
# Optimal control from the explicit solution: [ 0.  0.]
# Optimal control from the implicit solution: [ -6.41087183e-12   5.76410031e-11]
