# %% [markdown]
# # Cart Pole MPC Demo

# %% [markdown]
# This is a demo for the Model Predictive Control (MPC) package $\texttt{mpc_tools}$.

# %%
# %load_ext autoreload
#%autoreload 2
#%pylab notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import mpc_tools as mpc
import mpcqp as mqp

# %% [markdown]
# Here we stibilize a cart pole pendulum with: pole mass $m$, length $l$, and cart mass $M$, subject to the gravity acceleration $g$.

# %%
m = 1.
M = 1.
l = 1.
g = 10.

# %% [markdown]
# The linearized continuous-time dynamics is
# \begin{equation}
# \dot x =
# \begin{bmatrix}
# 0 & 0 & 0 & 1
# \\
# 0 & 0 & 0 & 1
# \\
# 0 & -mg/M & 0 & 0
# \\
# 0 & -(M+m)g/(Ml) & 0 & 0
# \end{bmatrix}
# x +
# \begin{bmatrix}
# 0
# \\
# 0
# \\
# 1/M
# \\
# 1/(Ml)
# \end{bmatrix}
# u.
# \end{equation}
# The discrete-time linear system can be defined from its continuous-time representation setting a sampling time $t_s$ (the exact zero-order-hold discretization is used).

# %%
A = np.array([
    [0., 0., 1., 0.,],
    [0., 0., 0., 1.,],
    [0., -m*g/M, 0., 0.,],
    [0., (M+m)*g/(l*M), 0., 0.,]
])
B = np.array([
    [0.],
    [0.], 
    [1./M], 
    [1./(l*M)]
])
t_s = .1
sys = mpc.DTLinearSystem.from_continuous(t_s, A, B)

# %% [markdown]
# At each each step, the following optimal control is solved
# \begin{align}
# \min \quad &
# \sum_{k=0}^{N-1} (x_k^T Q x_k + u_k^T R u_k) + x_N^T P x_N \\
# \text{subject to} \quad & x_{k+1} = A x_k + B u_k, \quad k = 0,1,\ldots,N-1, \\
# & x_0 \ \text{given}, \\
# & u_k \in \mathcal U, \quad k = 0,1,\ldots,N-1, \\
# & x_k \in \mathcal X, \quad k = 1,2,\ldots,N-1, \\
# & x_N \in \mathcal X_N, \\
# \end{align}
# By default $P=Q$ but, for staibility reasons, sometimes it's preferable to use the solution of the Discrete Algebraic Ricccati Equation (DARE)
# \begin{equation}
# P = (A+BK)^T P (A+BK) + Q + K^T R K
# \end{equation}
# where $K = -(B^T P B + R)^{-1} B^T P A$ is the optimal feedback $u_k = K x_k$.
# This can be done setting $\texttt{terminal_cost = 'dare'}$.

# %%
N = 3
Q = np.eye(A.shape[0])/100.
R = np.eye(B.shape[1])
terminal_cost = 'dare'
factory = mqp.MPCQPFactory(sys, N, Q, R, terminal_cost)

# %% [markdown]
# Input and state constraints have to be linear and they can be enforced as bounds (e.g., $u_{max} \geq u_k \geq u_{min}$) or as generic linear inqualities (e.g., $C u_k \leq C$).

# %%
x_max = np.array([
    [5.],
    [np.pi/6.],
    [5.],
    [np.pi/20./(N*t_s)]
])
x_min = -x_max
factory.add_state_bound(x_max, x_min)
u_max = np.array([[10.]])
u_min = -u_max
factory.add_input_bound(u_max, u_min)

# %% [markdown]
# To ensure stability of the closed loop system two terminal constraints are available:
#
# 1) $\texttt{terminal_constraint = 'origin'}$: this option imposes $x_N = 0$ which is sufficient to ensure stability (regardless the terminal cost) but in most cases it's excessive.
#
# 2) $\texttt{terminal_constraint = 'moas'}$: this option imposes $\mathcal{X}_N \in \mathcal{O}_{\infty}$ where $\mathcal{O}_{\infty}$ denotes the Maximum Output Admissible Set for the system closed loop system $x_{k+1} = (A + BK) x_k$, with $K$ derived from the DARE.
# Mathematically speaking, we have that $x_N \in \mathcal{O}_{\infty} \Leftrightarrow \{ x_k \in \mathcal{X} \wedge u_k \in \mathcal{U} \} \ \forall k \geq N$.
# This constraint, if coupoled with the DARE terminal cost, is sufficient condition for the stability of the closed loop system.

# %%
terminal_constraint = None
factory.set_terminal_constraint(terminal_constraint)

# %% [markdown]
# We now assemble the controller and simulate the closed loop system for $N_{sim}$ steps starting from the initial condition $x_0$.

# %%
qp = factory.assemble()
controller = mpc.MPCController(qp, sys.n_u)
N_sim = 50
x_0 = np.array([
    [0.],
    [np.pi/20.],
    [0.],
    [0.]
])
u = []
x = []
x.append(x_0)
for k in range(0, N_sim):
    u.append(controller.feedback(x[k]))
    x.append(sys.A.dot(x[k]) + sys.B.dot(u[k]))
x = sys.simulate(x_0, N_sim, u)

# %% [markdown]
# We can plot the solution using the functions $\texttt{plot_input_sequence(.)}$ and $\texttt{plot_state_trajectory(.)}$

# %%
mpc.plot_input_sequence(u, t_s, N_sim, u_max, u_min)
plt.show()
mpc.plot_state_trajectory(x, t_s, N_sim, x_max, x_min)
plt.show()

# %% [markdown]
# We can get the explict solution of the optimal control problem and plot the consequent state partition.

# %%
controller.compute_explicit_solution()
# Out:
# Computing critical region for the active set []
# Computing critical region for the active set [0]
# Computing critical region for the active set [1]
# Computing critical region for the active set [6]
# Computing critical region for the active set [8]
# Computing critical region for the active set [9]
# Computing critical region for the active set [10]
# Computing critical region for the active set [12]
# Computing critical region for the active set [13]
# Computing critical region for the active set [14]
# Computing critical region for the active set [15]
# Computing critical region for the active set [16]
# Computing critical region for the active set [17]
# Computing critical region for the active set [18]
# Computing critical region for the active set [19]
# Computing critical region for the active set [20]
# Computing critical region for the active set [22]
# Computing critical region for the active set [23]
# Computing critical region for the active set [24]
# Computing critical region for the active set [26]
# Computing critical region for the active set [27]
# Computing critical region for the active set [0, 2]
# LICQ does not hold for the active set [0, 6]
#     corrected active set [6]
# Computing critical region for the active set [6]
# LICQ does not hold for the active set [0, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 16]
# Computing critical region for the active set [0, 17]
# Computing critical region for the active set [0, 20]
# Computing critical region for the active set [0, 22]
# Computing critical region for the active set [0, 23]
# Computing critical region for the active set [0, 24]
# Computing critical region for the active set [1, 3]
# LICQ does not hold for the active set [1, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10]
#     corrected active set [10]
# Computing critical region for the active set [10]
# Computing critical region for the active set [1, 14]
# Computing critical region for the active set [1, 19]
# Computing critical region for the active set [1, 20]
# Computing critical region for the active set [1, 24]
# Computing critical region for the active set [1, 26]
# Computing critical region for the active set [1, 27]
# Computing critical region for the active set [2, 6]
# LICQ does not hold for the active set [6, 9]
#     corrected active set [6, 9]
# Computing critical region for the active set [6, 9]
# LICQ does not hold for the active set [6, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 14]
# Computing critical region for the active set [6, 16]
# Computing critical region for the active set [6, 18]
# Computing critical region for the active set [6, 19]
# Computing critical region for the active set [6, 20]
# Computing critical region for the active set [6, 23]
# Computing critical region for the active set [6, 26]
# Computing critical region for the active set [6, 27]
# LICQ does not hold for the active set [8, 9]
#     corrected active set [9]
# Computing critical region for the active set [9]
# LICQ does not hold for the active set [8, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [8, 15]
# Computing critical region for the active set [8, 19]
# Computing critical region for the active set [8, 20]
# LICQ does not hold for the active set [9, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 12]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 14]
# Computing critical region for the active set [9, 15]
# Computing critical region for the active set [9, 16]
# Computing critical region for the active set [9, 17]
# Computing critical region for the active set [9, 18]
# Computing critical region for the active set [9, 20]
# Computing critical region for the active set [9, 22]
# Computing critical region for the active set [9, 24]
# Computing critical region for the active set [9, 26]
# Computing critical region for the active set [3, 10]
# LICQ does not hold for the active set [10, 13]
#     corrected active set [10, 13]
# Computing critical region for the active set [10, 13]
# Computing critical region for the active set [10, 15]
# Computing critical region for the active set [10, 16]
# Computing critical region for the active set [10, 17]
# Computing critical region for the active set [10, 19]
# Computing critical region for the active set [10, 22]
# Computing critical region for the active set [10, 23]
# Computing critical region for the active set [10, 24]
# Computing critical region for the active set [10, 27]
# LICQ does not hold for the active set [12, 13]
#     corrected active set [13]
# Computing critical region for the active set [13]
# Computing critical region for the active set [12, 16]
# Computing critical region for the active set [12, 18]
# Computing critical region for the active set [12, 24]
# Computing critical region for the active set [13, 14]
# Computing critical region for the active set [13, 15]
# Computing critical region for the active set [13, 17]
# Computing critical region for the active set [13, 18]
# Computing critical region for the active set [13, 19]
# Computing critical region for the active set [13, 20]
# Computing critical region for the active set [13, 22]
# Computing critical region for the active set [13, 24]
# Computing critical region for the active set [13, 26]
# Computing critical region for the active set [14, 19]
# Computing critical region for the active set [14, 20]
# Computing critical region for the active set [15, 20]
# Computing critical region for the active set [15, 22]
# Computing critical region for the active set [16, 17]
# Computing critical region for the active set [16, 20]
# Computing critical region for the active set [16, 22]
# Computing critical region for the active set [16, 23]
# Computing critical region for the active set [16, 24]
# Computing critical region for the active set [17, 24]
# Computing critical region for the active set [18, 24]
# Computing critical region for the active set [18, 26]
# Computing critical region for the active set [19, 20]
# Computing critical region for the active set [19, 24]
# Computing critical region for the active set [19, 26]
# Computing critical region for the active set [19, 27]
# Computing critical region for the active set [4, 20]
# Computing critical region for the active set [20, 22]
# Computing critical region for the active set [20, 23]
# Computing critical region for the active set [22, 23]
# Computing critical region for the active set [5, 24]
# Computing critical region for the active set [24, 26]
# Computing critical region for the active set [24, 27]
# Computing critical region for the active set [26, 27]
# Computing critical region for the active set [0, 2, 4]
# LICQ does not hold for the active set [0, 2, 6]
#     corrected active set [2, 6]
# Computing critical region for the active set [2, 6]
# LICQ does not hold for the active set [0, 2, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 13]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 20]
# Computing critical region for the active set [0, 2, 22]
# Computing critical region for the active set [0, 2, 23]
# Computing critical region for the active set [0, 2, 24]
# LICQ does not hold for the active set [0, 6, 16]
#     corrected active set [6, 16]
# Computing critical region for the active set [6, 16]
# LICQ does not hold for the active set [0, 9, 16]
#     corrected active set [0, 16]
# Computing critical region for the active set [0, 16]
# LICQ does not hold for the active set [0, 10, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 16, 20]
# Computing critical region for the active set [0, 16, 23]
# Computing critical region for the active set [0, 16, 24]
# LICQ does not hold for the active set [0, 10, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 17, 23]
# Computing critical region for the active set [0, 17, 24]
# Computing critical region for the active set [0, 4, 20]
# LICQ does not hold for the active set [0, 6, 20]
#     corrected active set [6, 20]
# Computing critical region for the active set [6, 20]
# LICQ does not hold for the active set [0, 9, 20]
#     corrected active set [9, 20]
# Computing critical region for the active set [9, 20]
# LICQ does not hold for the active set [0, 13, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 19, 20]
# Computing critical region for the active set [0, 20, 22]
# Computing critical region for the active set [0, 20, 23]
# LICQ does not hold for the active set [0, 10, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 22]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 15, 22]
# Computing critical region for the active set [0, 16, 22]
# Computing critical region for the active set [0, 22, 23]
# LICQ does not hold for the active set [0, 6, 23]
#     corrected active set [6, 23]
# Computing critical region for the active set [6, 23]
# LICQ does not hold for the active set [0, 10, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 23]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 23, 24]
# LICQ does not hold for the active set [0, 12, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 24]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 5]
# LICQ does not hold for the active set [1, 3, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 10]
#     corrected active set [3, 10]
# Computing critical region for the active set [3, 10]
# LICQ does not hold for the active set [1, 3, 14]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 20]
# Computing critical region for the active set [1, 3, 24]
# Computing critical region for the active set [1, 3, 26]
# Computing critical region for the active set [1, 3, 27]
# LICQ does not hold for the active set [1, 6, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 14, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 14, 20]
# Computing critical region for the active set [1, 14, 27]
# LICQ does not hold for the active set [1, 6, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 19]
#     corrected active set [10, 19]
# Computing critical region for the active set [10, 19]
# LICQ does not hold for the active set [1, 13, 19]
#     corrected active set [13, 19]
# Computing critical region for the active set [13, 19]
# Computing critical region for the active set [1, 19, 20]
# Computing critical region for the active set [1, 19, 24]
# Computing critical region for the active set [1, 19, 27]
# LICQ does not hold for the active set [1, 8, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 20, 27]
# Computing critical region for the active set [1, 5, 24]
# LICQ does not hold for the active set [1, 9, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 24]
#     corrected active set [10, 24]
# Computing critical region for the active set [10, 24]
# LICQ does not hold for the active set [1, 13, 24]
#     corrected active set [13, 24]
# Computing critical region for the active set [13, 24]
# Computing critical region for the active set [1, 16, 24]
# Computing critical region for the active set [1, 24, 26]
# Computing critical region for the active set [1, 24, 27]
# LICQ does not hold for the active set [1, 6, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 18, 26]
# Computing critical region for the active set [1, 19, 26]
# Computing critical region for the active set [1, 26, 27]
# LICQ does not hold for the active set [1, 6, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 27]
#     corrected active set [10, 27]
# Computing critical region for the active set [10, 27]
# LICQ does not hold for the active set [1, 2, 6]
#     unfeasible critical region detected
# Computing critical region for the active set [2, 4, 6]
# LICQ does not hold for the active set [2, 6, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 6, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [2, 6, 20]
# Computing critical region for the active set [2, 6, 23]
# Empty critical region detected
# LICQ does not hold for the active set [6, 9, 14]
#     corrected active set [9, 14]
# Computing critical region for the active set [9, 14]
# LICQ does not hold for the active set [6, 13, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 14, 19]
#     corrected active set [14, 19]
# Computing critical region for the active set [14, 19]
# Computing critical region for the active set [6, 14, 20]
# LICQ does not hold for the active set [1, 6, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 9, 16]
#     corrected active set [9, 16]
# Computing critical region for the active set [9, 16]
# LICQ does not hold for the active set [6, 12, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 16, 20]
# Computing critical region for the active set [6, 16, 23]
# LICQ does not hold for the active set [1, 6, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 9, 18]
#     corrected active set [6, 9, 18]
# Computing critical region for the active set [6, 9, 18]
# LICQ does not hold for the active set [6, 12, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 13, 18]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 18, 26]
# LICQ does not hold for the active set [6, 13, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 19, 26]
# Computing critical region for the active set [6, 19, 27]
# LICQ does not hold for the active set [1, 6, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [4, 6, 20]
# LICQ does not hold for the active set [6, 9, 20]
#     corrected active set [9, 20]
# Computing critical region for the active set [9, 20]
# LICQ does not hold for the active set [6, 13, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 19, 20]
# Computing critical region for the active set [6, 20, 23]
# LICQ does not hold for the active set [1, 6, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 12, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 9, 26]
#     corrected active set [9, 26]
# Computing critical region for the active set [9, 26]
# LICQ does not hold for the active set [6, 13, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [6, 26, 27]
# LICQ does not hold for the active set [1, 8, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 9, 15]
#     corrected active set [9, 15]
# Computing critical region for the active set [9, 15]
# LICQ does not hold for the active set [8, 10, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 13, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [8, 15, 20]
# Computing critical region for the active set [8, 15, 22]
# LICQ does not hold for the active set [8, 10, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 13, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [8, 19, 20]
# Computing critical region for the active set [8, 19, 27]
# LICQ does not hold for the active set [8, 9, 20]
#     corrected active set [9, 20]
# Computing critical region for the active set [9, 20]
# LICQ does not hold for the active set [8, 13, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [8, 20, 22]
# Computing critical region for the active set [9, 14, 20]
# LICQ does not hold for the active set [1, 9, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 15, 20]
# Computing critical region for the active set [9, 15, 22]
# LICQ does not hold for the active set [1, 9, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 12, 16]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 16, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 16, 20]
# Computing critical region for the active set [9, 16, 22]
# Computing critical region for the active set [9, 16, 23]
# Computing critical region for the active set [9, 16, 24]
# LICQ does not hold for the active set [1, 9, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 17, 24]
# LICQ does not hold for the active set [1, 9, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 12, 18]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 18, 24]
# Computing critical region for the active set [9, 18, 26]
# Computing critical region for the active set [4, 9, 20]
# Computing critical region for the active set [9, 19, 20]
# Computing critical region for the active set [9, 20, 22]
# Computing critical region for the active set [9, 20, 23]
# LICQ does not hold for the active set [1, 9, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 22]
#     unfeasible critical region detected
# Computing critical region for the active set [5, 9, 24]
# LICQ does not hold for the active set [9, 10, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 12, 24]
#     unfeasible critical region detected
# Computing critical region for the active set [9, 24, 26]
# LICQ does not hold for the active set [0, 3, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [3, 5, 10]
# LICQ does not hold for the active set [3, 8, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 9, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [3, 10, 24]
# Computing critical region for the active set [3, 10, 27]
# Empty critical region detected
# LICQ does not hold for the active set [0, 10, 15]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 15]
#     corrected active set [13, 15]
# Computing critical region for the active set [13, 15]
# Computing critical region for the active set [10, 15, 22]
# LICQ does not hold for the active set [10, 16, 17]
#     corrected active set [10, 16, 17]
# Computing critical region for the active set [10, 16, 17]
# Computing critical region for the active set [10, 16, 22]
# Computing critical region for the active set [10, 16, 23]
# LICQ does not hold for the active set [10, 13, 17]
#     corrected active set [13, 17]
# Computing critical region for the active set [13, 17]
# Computing critical region for the active set [10, 17, 24]
# LICQ does not hold for the active set [0, 10, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 19]
#     corrected active set [13, 19]
# Computing critical region for the active set [13, 19]
# Computing critical region for the active set [10, 19, 24]
# Computing critical region for the active set [10, 19, 27]
# LICQ does not hold for the active set [10, 13, 22]
#     corrected active set [13, 22]
# Computing critical region for the active set [13, 22]
# Computing critical region for the active set [10, 22, 23]
# LICQ does not hold for the active set [0, 10, 24]
#     unfeasible critical region detected
# Computing critical region for the active set [5, 10, 24]
# LICQ does not hold for the active set [10, 13, 24]
#     corrected active set [13, 24]
# Computing critical region for the active set [13, 24]
# Computing critical region for the active set [10, 16, 24]
# Computing critical region for the active set [10, 24, 27]
# LICQ does not hold for the active set [0, 10, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [8, 10, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [12, 16, 23]
# Computing critical region for the active set [12, 16, 24]
# LICQ does not hold for the active set [0, 12, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 13, 18]
#     corrected active set [13, 18]
# Computing critical region for the active set [13, 18]
# Computing critical region for the active set [12, 18, 24]
# Computing critical region for the active set [12, 18, 26]
# LICQ does not hold for the active set [12, 13, 24]
#     corrected active set [13, 24]
# Computing critical region for the active set [13, 24]
# Computing critical region for the active set [12, 24, 26]
# LICQ does not hold for the active set [0, 13, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 14, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 14, 20]
# LICQ does not hold for the active set [0, 13, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 15, 20]
# Computing critical region for the active set [13, 15, 22]
# Computing critical region for the active set [13, 17, 24]
# LICQ does not hold for the active set [0, 13, 18]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 18, 24]
# Computing critical region for the active set [13, 18, 26]
# LICQ does not hold for the active set [0, 13, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 19, 20]
# Computing critical region for the active set [13, 19, 24]
# Computing critical region for the active set [13, 19, 26]
# Computing critical region for the active set [13, 19, 27]
# Computing critical region for the active set [4, 13, 20]
# Computing critical region for the active set [13, 20, 22]
# Computing critical region for the active set [5, 13, 24]
# Computing critical region for the active set [13, 16, 24]
# Computing critical region for the active set [13, 24, 26]
# Computing critical region for the active set [13, 24, 27]
# LICQ does not hold for the active set [0, 13, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [14, 19, 20]
# Computing critical region for the active set [14, 19, 27]
# Computing critical region for the active set [15, 20, 22]
# Computing critical region for the active set [15, 16, 22]
# Computing critical region for the active set [16, 17, 23]
# Computing critical region for the active set [16, 17, 24]
# Computing critical region for the active set [16, 20, 22]
# Computing critical region for the active set [16, 20, 23]
# Computing critical region for the active set [16, 22, 23]
# Computing critical region for the active set [16, 23, 24]
# Computing critical region for the active set [5, 16, 24]
# Computing critical region for the active set [16, 21, 24]
# Computing critical region for the active set [16, 24, 26]
# Computing critical region for the active set [18, 24, 26]
# Computing critical region for the active set [18, 19, 26]
# Computing critical region for the active set [4, 19, 20]
# Computing critical region for the active set [19, 20, 22]
# Computing critical region for the active set [19, 20, 25]
# Computing critical region for the active set [19, 20, 27]
# Computing critical region for the active set [19, 24, 26]
# Computing critical region for the active set [19, 24, 27]
# Computing critical region for the active set [19, 26, 27]
# Computing critical region for the active set [4, 11, 20]
# Computing critical region for the active set [4, 20, 22]
# Computing critical region for the active set [4, 20, 25]
# Computing critical region for the active set [20, 22, 23]
# Computing critical region for the active set [20, 22, 27]
# Computing critical region for the active set [5, 7, 24]
# Computing critical region for the active set [5, 21, 24]
# Computing critical region for the active set [5, 24, 26]
# Computing critical region for the active set [23, 24, 26]
# Computing critical region for the active set [24, 26, 27]
# LICQ does not hold for the active set [0, 2, 4, 6]
#     corrected active set [2, 4, 6]
# Computing critical region for the active set [2, 4, 6]
# LICQ does not hold for the active set [0, 2, 4, 10]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 11]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 13]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 17]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 20]
#     corrected active set [0, 4, 20]
# Computing critical region for the active set [0, 4, 20]
# LICQ does not hold for the active set [0, 2, 4, 22]
#     corrected active set [0, 2, 22]
# Computing critical region for the active set [0, 2, 22]
# LICQ does not hold for the active set [0, 2, 4, 23]
#     corrected active set [0, 2, 23]
# Computing critical region for the active set [0, 2, 23]
# LICQ does not hold for the active set [0, 2, 4, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 4, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 6, 20]
#     corrected active set [2, 6, 20]
# Computing critical region for the active set [2, 6, 20]
# LICQ does not hold for the active set [0, 2, 13, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 20, 22]
#     corrected active set [0, 2, 22]
# Computing critical region for the active set [0, 2, 22]
# LICQ does not hold for the active set [0, 2, 20, 23]
#     corrected active set [0, 2, 23]
# Computing critical region for the active set [0, 2, 23]
# LICQ does not hold for the active set [0, 2, 10, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 11, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 13, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 15, 22]
#     corrected active set [0, 15, 22]
# Computing critical region for the active set [0, 15, 22]
# LICQ does not hold for the active set [0, 2, 16, 22]
#     corrected active set [0, 16, 22]
# Computing critical region for the active set [0, 16, 22]
# LICQ does not hold for the active set [0, 2, 22, 23]
#     corrected active set [0, 2, 23]
# Computing critical region for the active set [0, 2, 23]
# LICQ does not hold for the active set [0, 2, 22, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 6, 23]
#     corrected active set [2, 6, 23]
# Computing critical region for the active set [2, 6, 23]
# LICQ does not hold for the active set [0, 2, 10, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 11, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 12, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 13, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 16, 23]
#     corrected active set [0, 16, 23]
# Computing critical region for the active set [0, 16, 23]
# LICQ does not hold for the active set [0, 2, 17, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 12, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 13, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 16, 24]
#     corrected active set [0, 16, 24]
# Computing critical region for the active set [0, 16, 24]
# LICQ does not hold for the active set [0, 2, 17, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 16, 20]
#     corrected active set [6, 16, 20]
# Computing critical region for the active set [6, 16, 20]
# LICQ does not hold for the active set [0, 16, 20, 23]
#     corrected active set [0, 16, 23]
# Computing critical region for the active set [0, 16, 23]
# LICQ does not hold for the active set [0, 6, 16, 23]
#     corrected active set [6, 16, 23]
# Computing critical region for the active set [6, 16, 23]
# LICQ does not hold for the active set [0, 9, 16, 23]
#     corrected active set [9, 16, 23]
# Computing critical region for the active set [9, 16, 23]
# LICQ does not hold for the active set [0, 10, 16, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 16, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 16, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 17, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 22, 23]
#     corrected active set [0, 16, 22]
# Computing critical region for the active set [0, 16, 22]
# LICQ does not hold for the active set [0, 16, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9, 16, 24]
#     corrected active set [9, 16, 24]
# Computing critical region for the active set [9, 16, 24]
# LICQ does not hold for the active set [0, 10, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 17, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 24, 26]
#     corrected active set [16, 24, 26]
# Computing critical region for the active set [16, 24, 26]
# LICQ does not hold for the active set [0, 10, 17, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 17, 23, 24]
#     corrected active set [0, 23, 24]
# Computing critical region for the active set [0, 23, 24]
# LICQ does not hold for the active set [0, 10, 17, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 17, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 20]
#     corrected active set [4, 6, 20]
# Computing critical region for the active set [4, 6, 20]
# LICQ does not hold for the active set [0, 4, 9, 20]
#     corrected active set [4, 9, 20]
# Computing critical region for the active set [4, 9, 20]
# LICQ does not hold for the active set [0, 4, 11, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 13, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 19, 20]
#     corrected active set [4, 19, 20]
# Computing critical region for the active set [4, 19, 20]
# LICQ does not hold for the active set [0, 4, 20, 22]
#     corrected active set [0, 20, 22]
# Computing critical region for the active set [0, 20, 22]
# LICQ does not hold for the active set [0, 4, 20, 23]
#     corrected active set [0, 20, 23]
# Computing critical region for the active set [0, 20, 23]
# LICQ does not hold for the active set [0, 4, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 19, 20, 22]
#     corrected active set [0, 20, 22]
# Computing critical region for the active set [0, 20, 22]
# LICQ does not hold for the active set [0, 8, 20, 22]
#     corrected active set [8, 20, 22]
# Computing critical region for the active set [8, 20, 22]
# LICQ does not hold for the active set [0, 9, 20, 22]
#     corrected active set [9, 20, 22]
# Computing critical region for the active set [9, 20, 22]
# LICQ does not hold for the active set [0, 11, 20, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 20, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 15, 20, 22]
#     corrected active set [0, 15, 22]
# Computing critical region for the active set [0, 15, 22]
# LICQ does not hold for the active set [0, 16, 20, 22]
#     corrected active set [0, 16, 22]
# Computing critical region for the active set [0, 16, 22]
# LICQ does not hold for the active set [0, 20, 22, 23]
#     corrected active set [0, 20, 23]
# Computing critical region for the active set [0, 20, 23]
# LICQ does not hold for the active set [0, 20, 22, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 20, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 20, 23]
#     corrected active set [6, 20, 23]
# Computing critical region for the active set [6, 20, 23]
# LICQ does not hold for the active set [0, 9, 20, 23]
#     corrected active set [9, 20, 23]
# Computing critical region for the active set [9, 20, 23]
# LICQ does not hold for the active set [0, 11, 20, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 8, 15, 22]
#     corrected active set [8, 15, 22]
# Computing critical region for the active set [8, 15, 22]
# LICQ does not hold for the active set [0, 9, 15, 22]
#     corrected active set [9, 15, 22]
# Computing critical region for the active set [9, 15, 22]
# LICQ does not hold for the active set [0, 10, 15, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 15, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 15, 16, 22]
#     corrected active set [0, 16, 22]
# Computing critical region for the active set [0, 16, 22]
# LICQ does not hold for the active set [0, 15, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9, 16, 22]
#     corrected active set [9, 16, 22]
# Computing critical region for the active set [9, 16, 22]
# LICQ does not hold for the active set [0, 10, 16, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 16, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 16, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 22, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 7]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 8]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 9]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 10]
#     corrected active set [3, 5, 10]
# Computing critical region for the active set [3, 5, 10]
# LICQ does not hold for the active set [1, 3, 5, 14]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 5, 24]
#     corrected active set [1, 5, 24]
# Computing critical region for the active set [1, 5, 24]
# LICQ does not hold for the active set [1, 3, 5, 26]
#     corrected active set [1, 3, 26]
# Computing critical region for the active set [1, 3, 26]
# LICQ does not hold for the active set [1, 3, 5, 27]
#     corrected active set [1, 3, 27]
# Computing critical region for the active set [1, 3, 27]
# LICQ does not hold for the active set [1, 3, 8, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 9, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 14, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 19, 20]
#     corrected active set [1, 19, 20]
# Computing critical region for the active set [1, 19, 20]
# LICQ does not hold for the active set [1, 3, 20, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 9, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 10, 24]
#     corrected active set [3, 10, 24]
# Computing critical region for the active set [3, 10, 24]
# LICQ does not hold for the active set [1, 3, 24, 26]
#     corrected active set [1, 3, 26]
# Computing critical region for the active set [1, 3, 26]
# LICQ does not hold for the active set [1, 3, 24, 27]
#     corrected active set [1, 3, 27]
# Computing critical region for the active set [1, 3, 27]
# LICQ does not hold for the active set [1, 3, 6, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 9, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 18, 26]
#     corrected active set [1, 18, 26]
# Computing critical region for the active set [1, 18, 26]
# LICQ does not hold for the active set [1, 3, 19, 26]
#     corrected active set [1, 19, 26]
# Computing critical region for the active set [1, 19, 26]
# LICQ does not hold for the active set [1, 3, 21, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 26, 27]
#     corrected active set [1, 3, 27]
# Computing critical region for the active set [1, 3, 27]
# LICQ does not hold for the active set [1, 3, 6, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 8, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 9, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 10, 27]
#     corrected active set [3, 10, 27]
# Computing critical region for the active set [3, 10, 27]
# LICQ does not hold for the active set [1, 3, 14, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 19, 27]
#     corrected active set [1, 19, 27]
# Computing critical region for the active set [1, 19, 27]
# LICQ does not hold for the active set [1, 6, 14, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 14, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 14, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 14, 20, 27]
#     corrected active set [1, 20, 27]
# Computing critical region for the active set [1, 20, 27]
# LICQ does not hold for the active set [1, 6, 14, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 14, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 19, 20]
#     corrected active set [13, 19, 20]
# Computing critical region for the active set [13, 19, 20]
# LICQ does not hold for the active set [1, 19, 20, 22]
#     corrected active set [19, 20, 22]
# Computing critical region for the active set [19, 20, 22]
# LICQ does not hold for the active set [1, 19, 20, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 19, 24]
#     corrected active set [10, 19, 24]
# Computing critical region for the active set [10, 19, 24]
# LICQ does not hold for the active set [1, 19, 24, 27]
#     corrected active set [1, 19, 27]
# Computing critical region for the active set [1, 19, 27]
# LICQ does not hold for the active set [1, 6, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 8, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 19, 27]
#     corrected active set [10, 19, 27]
# Computing critical region for the active set [10, 19, 27]
# LICQ does not hold for the active set [1, 13, 19, 27]
#     corrected active set [13, 19, 27]
# Computing critical region for the active set [13, 19, 27]
# LICQ does not hold for the active set [1, 19, 26, 27]
#     corrected active set [1, 19, 26]
# Computing critical region for the active set [1, 19, 26]
# LICQ does not hold for the active set [1, 8, 20, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 7, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 9, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 10, 24]
#     corrected active set [5, 10, 24]
# Computing critical region for the active set [5, 10, 24]
# LICQ does not hold for the active set [1, 5, 13, 24]
#     corrected active set [5, 13, 24]
# Computing critical region for the active set [5, 13, 24]
# LICQ does not hold for the active set [1, 5, 16, 24]
#     corrected active set [5, 16, 24]
# Computing critical region for the active set [5, 16, 24]
# LICQ does not hold for the active set [1, 5, 21, 24]
#     corrected active set [1, 21, 24]
# Computing critical region for the active set [1, 21, 24]
# LICQ does not hold for the active set [1, 5, 24, 26]
#     corrected active set [1, 24, 26]
# Computing critical region for the active set [1, 24, 26]
# LICQ does not hold for the active set [1, 5, 24, 27]
#     corrected active set [1, 24, 27]
# Computing critical region for the active set [1, 24, 27]
# LICQ does not hold for the active set [1, 9, 16, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 16, 24, 26]
#     corrected active set [1, 24, 26]
# Computing critical region for the active set [1, 24, 26]
# LICQ does not hold for the active set [1, 7, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 24, 26]
#     corrected active set [12, 24, 26]
# Computing critical region for the active set [12, 24, 26]
# LICQ does not hold for the active set [1, 13, 24, 26]
#     corrected active set [13, 24, 26]
# Computing critical region for the active set [13, 24, 26]
# LICQ does not hold for the active set [1, 18, 24, 26]
#     corrected active set [1, 18, 26]
# Computing critical region for the active set [1, 18, 26]
# LICQ does not hold for the active set [1, 19, 24, 26]
#     corrected active set [1, 19, 26]
# Computing critical region for the active set [1, 19, 26]
# LICQ does not hold for the active set [1, 21, 24, 26]
#     corrected active set [1, 21, 24]
# Computing critical region for the active set [1, 21, 24]
# LICQ does not hold for the active set [1, 23, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 24, 26, 27]
#     corrected active set [1, 24, 27]
# Computing critical region for the active set [1, 24, 27]
# LICQ does not hold for the active set [1, 7, 24, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 24, 27]
#     corrected active set [10, 24, 27]
# Computing critical region for the active set [10, 24, 27]
# LICQ does not hold for the active set [1, 13, 24, 27]
#     corrected active set [13, 24, 27]
# Computing critical region for the active set [13, 24, 27]
# LICQ does not hold for the active set [1, 6, 18, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 18, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 18, 26]
#     corrected active set [12, 18, 26]
# Computing critical region for the active set [12, 18, 26]
# LICQ does not hold for the active set [1, 13, 18, 26]
#     corrected active set [13, 18, 26]
# Computing critical region for the active set [13, 18, 26]
# LICQ does not hold for the active set [1, 18, 19, 26]
#     corrected active set [1, 19, 26]
# Computing critical region for the active set [1, 19, 26]
# LICQ does not hold for the active set [1, 18, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 19, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 19, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 19, 26]
#     corrected active set [13, 19, 26]
# Computing critical region for the active set [13, 19, 26]
# LICQ does not hold for the active set [1, 19, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 6, 26, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 4, 6]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 6, 11]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 6, 12]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 6, 13]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 4, 6, 20]
#     corrected active set [4, 6, 20]
# Computing critical region for the active set [4, 6, 20]
# LICQ does not hold for the active set [2, 4, 6, 23]
#     corrected active set [2, 6, 23]
# Computing critical region for the active set [2, 6, 23]
# LICQ does not hold for the active set [2, 4, 6, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 6, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 6, 13, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 6, 20, 23]
#     corrected active set [2, 6, 23]
# Computing critical region for the active set [2, 6, 23]
# ...
# Empty critical region detected
# LICQ does not hold for the active set [10, 16, 22, 23]
#     corrected active set [10, 16, 23]
# Computing critical region for the active set [10, 16, 23]
# LICQ does not hold for the active set [10, 16, 17, 23]
#     corrected active set [16, 17, 23]
# Computing critical region for the active set [16, 17, 23]
# LICQ does not hold for the active set [10, 13, 17, 24]
#     corrected active set [13, 17, 24]
# Computing critical region for the active set [13, 17, 24]
# LICQ does not hold for the active set [10, 16, 17, 24]
#     corrected active set [16, 17, 24]
# Computing critical region for the active set [16, 17, 24]
# LICQ does not hold for the active set [0, 10, 19, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 19, 24]
#     corrected active set [13, 19, 24]
# Computing critical region for the active set [13, 19, 24]
# LICQ does not hold for the active set [10, 19, 24, 27]
#     corrected active set [10, 19, 27]
# Computing critical region for the active set [10, 19, 27]
# LICQ does not hold for the active set [0, 10, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 10, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 19, 27]
#     corrected active set [13, 19, 27]
# Computing critical region for the active set [13, 19, 27]
# LICQ does not hold for the active set [0, 5, 10, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 7, 10, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 10, 13, 24]
#     corrected active set [5, 13, 24]
# Computing critical region for the active set [5, 13, 24]
# LICQ does not hold for the active set [5, 10, 16, 24]
#     corrected active set [10, 16, 24]
# Computing critical region for the active set [10, 16, 24]
# LICQ does not hold for the active set [5, 10, 21, 24]
#     corrected active set [10, 21, 24]
# Computing critical region for the active set [10, 21, 24]
# LICQ does not hold for the active set [5, 10, 24, 27]
#     corrected active set [10, 24, 27]
# Computing critical region for the active set [10, 24, 27]
# LICQ does not hold for the active set [10, 13, 16, 24]
#     corrected active set [13, 16, 24]
# Computing critical region for the active set [13, 16, 24]
# LICQ does not hold for the active set [10, 16, 21, 24]
#     corrected active set [10, 21, 24]
# Computing critical region for the active set [10, 21, 24]
# LICQ does not hold for the active set [10, 16, 23, 24]
#     corrected active set [16, 23, 24]
# Computing critical region for the active set [16, 23, 24]
# LICQ does not hold for the active set [0, 10, 24, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 10, 24, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 24, 27]
#     corrected active set [13, 24, 27]
# Computing critical region for the active set [13, 24, 27]
# LICQ does not hold for the active set [12, 13, 16, 24]
#     corrected active set [13, 16, 24]
# Computing critical region for the active set [13, 16, 24]
# LICQ does not hold for the active set [12, 16, 23, 24]
#     corrected active set [16, 23, 24]
# Computing critical region for the active set [16, 23, 24]
# LICQ does not hold for the active set [12, 16, 24, 26]
#     corrected active set [12, 24, 26]
# Computing critical region for the active set [12, 24, 26]
# LICQ does not hold for the active set [0, 12, 18, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 13, 18, 24]
#     corrected active set [13, 18, 24]
# Computing critical region for the active set [13, 18, 24]
# LICQ does not hold for the active set [12, 18, 24, 26]
#     corrected active set [12, 18, 26]
# Computing critical region for the active set [12, 18, 26]
# LICQ does not hold for the active set [0, 12, 18, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 13, 18, 26]
#     corrected active set [13, 18, 26]
# Computing critical region for the active set [13, 18, 26]
# LICQ does not hold for the active set [12, 18, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 12, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 13, 24, 26]
#     corrected active set [13, 24, 26]
# Computing critical region for the active set [13, 24, 26]
# LICQ does not hold for the active set [12, 23, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 14, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 14, 19, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 15, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 15, 20, 22]
#     corrected active set [15, 20, 22]
# Computing critical region for the active set [15, 20, 22]
# LICQ does not hold for the active set [13, 16, 17, 24]
#     corrected active set [16, 17, 24]
# Computing critical region for the active set [16, 17, 24]
# LICQ does not hold for the active set [0, 13, 18, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 18, 24, 26]
#     corrected active set [13, 18, 26]
# Computing critical region for the active set [13, 18, 26]
# LICQ does not hold for the active set [0, 13, 18, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 18, 19, 26]
#     corrected active set [13, 19, 26]
# Computing critical region for the active set [13, 19, 26]
# LICQ does not hold for the active set [13, 18, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [4, 13, 19, 20]
#     corrected active set [4, 19, 20]
# Computing critical region for the active set [4, 19, 20]
# LICQ does not hold for the active set [13, 19, 20, 22]
#     corrected active set [19, 20, 22]
# Computing critical region for the active set [19, 20, 22]
# LICQ does not hold for the active set [13, 19, 20, 25]
#     corrected active set [19, 20, 25]
# Computing critical region for the active set [19, 20, 25]
# LICQ does not hold for the active set [13, 19, 20, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 19, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 19, 24, 26]
#     corrected active set [13, 19, 26]
# Computing critical region for the active set [13, 19, 26]
# LICQ does not hold for the active set [13, 19, 24, 27]
#     corrected active set [13, 19, 27]
# Computing critical region for the active set [13, 19, 27]
# LICQ does not hold for the active set [0, 13, 19, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 13, 19, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 19, 23, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 19, 26, 27]
#     corrected active set [13, 19, 27]
# Computing critical region for the active set [13, 19, 27]
# LICQ does not hold for the active set [0, 13, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 13, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 14, 19, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 20, 22, 27]
#     corrected active set [20, 22, 27]
# Computing critical region for the active set [20, 22, 27]
# LICQ does not hold for the active set [0, 5, 13, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 7, 13, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 13, 16, 24]
#     corrected active set [13, 16, 24]
# Computing critical region for the active set [13, 16, 24]
# LICQ does not hold for the active set [5, 13, 21, 24]
#     corrected active set [13, 21, 24]
# Computing critical region for the active set [13, 21, 24]
# LICQ does not hold for the active set [5, 13, 24, 26]
#     corrected active set [13, 24, 26]
# Computing critical region for the active set [13, 24, 26]
# LICQ does not hold for the active set [5, 13, 24, 27]
#     corrected active set [13, 24, 27]
# Computing critical region for the active set [13, 24, 27]
# LICQ does not hold for the active set [13, 16, 21, 24]
#     corrected active set [13, 21, 24]
# Computing critical region for the active set [13, 21, 24]
# LICQ does not hold for the active set [13, 16, 23, 24]
#     corrected active set [16, 23, 24]
# Computing critical region for the active set [16, 23, 24]
# LICQ does not hold for the active set [13, 16, 24, 26]
#     corrected active set [13, 24, 26]
# Computing critical region for the active set [13, 24, 26]
# LICQ does not hold for the active set [0, 13, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 13, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 21, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 23, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 24, 26, 27]
#     corrected active set [13, 24, 27]
# Computing critical region for the active set [13, 24, 27]
# LICQ does not hold for the active set [0, 13, 24, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 13, 24, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [14, 19, 20, 27]
#     corrected active set [19, 20, 27]
# Computing critical region for the active set [19, 20, 27]
# LICQ does not hold for the active set [15, 16, 20, 22]
#     corrected active set [16, 20, 22]
# Computing critical region for the active set [16, 20, 22]
# LICQ does not hold for the active set [15, 20, 22, 27]
#     corrected active set [20, 22, 27]
# Computing critical region for the active set [20, 22, 27]
# LICQ does not hold for the active set [16, 17, 23, 24]
#     corrected active set [16, 23, 24]
# Computing critical region for the active set [16, 23, 24]
# LICQ does not hold for the active set [16, 20, 22, 23]
#     corrected active set [16, 20, 23]
# Computing critical region for the active set [16, 20, 23]
# LICQ does not hold for the active set [16, 21, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [16, 23, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [5, 16, 21, 24]
#     corrected active set [16, 21, 24]
# Computing critical region for the active set [16, 21, 24]
# LICQ does not hold for the active set [5, 16, 24, 26]
#     corrected active set [16, 24, 26]
# Computing critical region for the active set [16, 24, 26]
# LICQ does not hold for the active set [1, 16, 21, 24]
#     corrected active set [1, 21, 24]
# Computing critical region for the active set [1, 21, 24]
# LICQ does not hold for the active set [16, 21, 24, 26]
#     corrected active set [16, 24, 26]
# Computing critical region for the active set [16, 24, 26]
# LICQ does not hold for the active set [18, 19, 24, 26]
#     corrected active set [19, 24, 26]
# Computing critical region for the active set [19, 24, 26]
# LICQ does not hold for the active set [18, 23, 24, 26]
#     corrected active set [23, 24, 26]
# Computing critical region for the active set [23, 24, 26]
# LICQ does not hold for the active set [4, 19, 20, 22]
#     corrected active set [19, 20, 22]
# Computing critical region for the active set [19, 20, 22]
# LICQ does not hold for the active set [4, 19, 20, 25]
#     corrected active set [19, 20, 25]
# Computing critical region for the active set [19, 20, 25]
# LICQ does not hold for the active set [19, 20, 22, 25]
#     corrected active set [19, 20, 25]
# Computing critical region for the active set [19, 20, 25]
# LICQ does not hold for the active set [19, 20, 22, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 19, 20, 25]
#     corrected active set [0, 20, 25]
# Computing critical region for the active set [0, 20, 25]
# LICQ does not hold for the active set [19, 20, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [19, 24, 26, 27]
#     corrected active set [19, 24, 27]
# Computing critical region for the active set [19, 24, 27]
# LICQ does not hold for the active set [4, 11, 20, 25]
#     corrected active set [4, 20, 25]
# Computing critical region for the active set [4, 20, 25]
# LICQ does not hold for the active set [4, 20, 22, 25]
#     corrected active set [4, 20, 25]
# Computing critical region for the active set [4, 20, 25]
# LICQ does not hold for the active set [5, 7, 21, 24]
#     corrected active set [5, 21, 24]
# Computing critical region for the active set [5, 21, 24]
# LICQ does not hold for the active set [5, 21, 24, 26]
#     corrected active set [5, 24, 26]
# Computing critical region for the active set [5, 24, 26]
# LICQ does not hold for the active set [1, 3, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 9, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 10, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 21, 24]
#     corrected active set [13, 21, 24]
# Computing critical region for the active set [13, 21, 24]
# LICQ does not hold for the active set [1, 21, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 20, 25]
#     corrected active set [0, 20, 25]
# Computing critical region for the active set [0, 20, 25]
# LICQ does not hold for the active set [1, 6, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 6, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 9, 20, 25]
#     corrected active set [9, 20, 25]
# Computing critical region for the active set [9, 20, 25]
# LICQ does not hold for the active set [6, 11, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 13, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [6, 20, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 9, 20, 25]
#     corrected active set [0, 20, 25]
# Computing critical region for the active set [0, 20, 25]
# LICQ does not hold for the active set [1, 9, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 11, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 20, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 10, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 10, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 10, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [9, 10, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [10, 13, 21, 24]
#     corrected active set [13, 21, 24]
# Computing critical region for the active set [13, 21, 24]
# LICQ does not hold for the active set [10, 21, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [7, 13, 21, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 21, 23, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 11, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 13, 20, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 20, 25, 27]
#     unfeasible critical region detected
#
# Explicit solution successfully computed in 5.843985 s:
# parameter space partitioned in 464 critical regions.

# %%
projections = [[0,1],[0,2],[0,3],[1,2],[1,3],[2,3]]
for prj in projections:
    for cr in controller.critical_regions:
        cr.polytope.plot(prj)
    plt.show()

# %% [markdown]
# The result from the explicit solution and the optimal control problem is, of course, the same: let's take $x_0$ for example.

# %%
u_explicit = controller.feedforward_explicit(x_0)
u_implicit = controller.feedforward(x_0)
print('Optimal control from the explicit solution: ' + str(u_explicit.flatten()))
print('Optimal control from the implicit solution: ' + str(u_implicit.flatten()))
# Out:
# Optimal control from the explicit solution: [-5.68545161 -3.31673346 -1.81178394]
# Optimal control from the implicit solution: [-5.68545161 -3.31673346 -1.81178394]
