# %% [markdown]
# # Linear Inverted Pendulum, MPC Demo

# %% [markdown]
# This is a demo for the Model Predictive Control (MPC) package $\texttt{mpc_tools}$.

# %%
# %load_ext autoreload
# %autoreload 2
#%pylab notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pympc.dynamical_systems as ds
import pympc.plot as mpc_plt
from pympc.control import MPCController, MPCExplicitController
from pympc.geometry import Polytope

# %% [markdown]
# We stabilize a linear inverted pendulum with mass $m$ and length $l$, subject to the gravity acceleration $g$.

# %%
m = 1.
l = 1.
g = 10.

# %% [markdown]
# The linearized continuous-time dynamics is
# \begin{equation}
# \dot x = A x + B u =
# \begin{bmatrix}
# 0 & 1 \\ g/l & 0
# \end{bmatrix}
# x +
# \begin{bmatrix}
# 0 \\ 1/(ml^2)
# \end{bmatrix}
# u.
# \end{equation}
# The discrete-time linear system can be defined from its continuous-time representation setting a sampling time $t_s$ (the exact zero-order-hold discretization is used).

# %%
A = np.array([
    [0., 1.],
    [g/l, 0.]
])
B = np.array([
    [0.],
    [1/(m*l**2.)]
])
t_s = .1
sys = ds.DTLinearSystem.from_continuous(A, B, t_s)

# %% [markdown]
# At each each step, the following optimal control is solved
# \begin{align}
# \min \quad &
# \sum_{k=0}^{N-1} (x_k^T Q x_k + u_k^T R u_k) + x_N^T P x_N \\
# \text{subject to} \quad & x_{k+1} = A x_k + B u_k, \quad k = 0,1,\ldots,N-1, \\
# & u_k \in \mathcal U, \quad k = 0,1,\ldots,N-1, \\
# & x_k \in \mathcal X, \quad k = 1,2,\ldots,N-1, \\
# & x_N \in \mathcal X_N, \\
# & x_0 \ \text{given}, \\
# \end{align}
# and the input $u_0$ is applied to the system.

# %%
N = 6
Q = np.eye(A.shape[0])
R = np.eye(B.shape[1])
objective_norm = 'two'

# %% [markdown]
# For stability reasons we set the terminal cost to be equal to the cost-to-go of the infinite-horizon LQR controller. To do that wesolve the Discrete Algebraic Ricccati Equation (DARE)
# \begin{equation}
# P = (A+BK)^T P (A+BK) + Q + K^T R K
# \end{equation}
# where $K = -(B^T P B + R)^{-1} B^T P A$ is the optimal feedback $u_k = K x_k$.

# %%
P, K = ds.dare(sys.A, sys.B, Q, R)

# %% [markdown]
# The admissible sets $\mathcal U$ and $\mathcal X$ have to be polytopes. These can be generated from a set of linear inequalities (e.g., $C u_k \leq c$) or from bounds (e.g., $u_{max} \geq u_k \geq u_{min}$).

# %%
u_max = np.array([[10.]])
u_min = -u_max
U = Polytope.from_bounds(u_min, u_max)
U.assemble()
x_max = np.array([[.5], [.5]])
x_min = -x_max
X = Polytope.from_bounds(x_min, x_max)
X.assemble()
# Out:
# <pympc.geometry.Polytope instance at 0x1049b7dd0>

# %% [markdown]
# The terminal constraint $x_N \in \mathcal X_N$ is generally used to ensure closed-loop stability and, like $\mathcal U$ and $\mathcal X$, it has to be a polytope; here we decide to guarantee stability throught the use of the Maximum Output Admissible Set (MOAS).
#
# Defining the closed-loop state-transition matrix $ \bar A = A + BK$, constraining $x_N$ to be in the MOAS we ensure that $ x_{k+1} = \bar A x_k \in \mathcal{X}$ and $u_k = K x_k \in \mathcal{U}, \forall k \geq N$. This, together with the use of the DARE solution as terminal cost, is sufficient condition for the stability of the closed loop system.

# %%
X_N = ds.moas_closed_loop(sys.A, sys.B, K, X, U)

# %% [markdown]
# Now we have all the ingredients to build the MPC controller.

# %%
controller = MPCController(sys, N, objective_norm, Q, R, P, X, U, X_N)

# %% [markdown]
# We then simulate the closed loop system for $N_{sim}$ steps starting from the initial condition $x_0$.

# %%
N_sim = 50
x_0 = np.array([[.45],[.5]])
u = []
x = []
x.append(x_0)
for k in range(N_sim):
    u.append(controller.feedback(x[k]))
    x.append(sys.A.dot(x[k]) + sys.B.dot(u[k]))

# %% [markdown]
# We can plot the solution using the functions $\texttt{plot_input_sequence(.)}$ and $\texttt{plot_state_trajectory(.)}$

# %%
mpc_plt.input_sequence(u, t_s, N_sim, (u_min, u_max))
plt.show()
mpc_plt.state_trajectory(x, t_s, N_sim, (x_min, x_max))
plt.show()

# %% [markdown]
# We can get the explict solution of the optimal control problem, solving the resulting Multi-Parametric Quadratic Program (mpQP).

# %%
mpqp = controller.condensed_program
explicit_controller = MPCExplicitController(mpqp)
# Out:
# Computing critical region for the active set []
# Computing critical region for the active set [0]
# Computing critical region for the active set [1]
# Computing critical region for the active set [13]
# Computing critical region for the active set [15]
# Computing critical region for the active set [17]
# Computing critical region for the active set [19]
# Computing critical region for the active set [21]
# Computing critical region for the active set [23]
# Computing critical region for the active set [24]
# Computing critical region for the active set [25]
# LICQ does not hold for the active set [0, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 24]
# Computing critical region for the active set [0, 26]
# LICQ does not hold for the active set [1, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 25]
# Computing critical region for the active set [1, 27]
# Computing critical region for the active set [13, 17]
# Computing critical region for the active set [15, 19]
# Computing critical region for the active set [17, 21]
# Computing critical region for the active set [19, 23]
# Computing critical region for the active set [21, 24]
# Computing critical region for the active set [23, 25]
# Computing critical region for the active set [0, 21, 24]
# Computing critical region for the active set [0, 24, 26]
# Computing critical region for the active set [0, 2, 26]
# LICQ does not hold for the active set [0, 15, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 23, 25]
# Computing critical region for the active set [1, 25, 27]
# Computing critical region for the active set [1, 3, 27]
# LICQ does not hold for the active set [1, 13, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 17, 21]
# LICQ does not hold for the active set [0, 15, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [15, 19, 23]
# Computing critical region for the active set [17, 21, 24]
# Computing critical region for the active set [19, 23, 25]
# Computing critical region for the active set [21, 24, 26]
# Computing critical region for the active set [23, 25, 27]
# Computing critical region for the active set [0, 21, 24, 26]
# Computing critical region for the active set [0, 2, 24, 26]
# LICQ does not hold for the active set [0, 14, 24, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 24, 26, 28]
# LICQ does not hold for the active set [0, 2, 15, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 26, 28]
# Computing critical region for the active set [1, 23, 25, 27]
# Computing critical region for the active set [1, 3, 25, 27]
# LICQ does not hold for the active set [1, 12, 25, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 25, 27, 29]
# LICQ does not hold for the active set [1, 3, 13, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 27, 29]
# LICQ does not hold for the active set [1, 13, 17, 21]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 17, 21, 24]
# LICQ does not hold for the active set [0, 15, 19, 23]
#     unfeasible critical region detected
# Computing critical region for the active set [15, 19, 23, 25]
# Computing critical region for the active set [17, 21, 24, 26]
# Computing critical region for the active set [19, 23, 25, 27]
# Computing critical region for the active set [14, 21, 24, 26]
# Computing critical region for the active set [12, 23, 25, 27]
# LICQ does not hold for the active set [0, 14, 21, 24, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 2, 24, 26, 28]
# LICQ does not hold for the active set [0, 14, 24, 26, 28]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 18, 24, 26, 28]
# LICQ does not hold for the active set [0, 2, 15, 26, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 23, 25, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 3, 25, 27, 29]
# LICQ does not hold for the active set [1, 12, 25, 27, 29]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 16, 25, 27, 29]
# LICQ does not hold for the active set [1, 3, 13, 27, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 17, 21, 24]
#     unfeasible critical region detected
# Computing critical region for the active set [13, 17, 21, 24, 26]
# LICQ does not hold for the active set [0, 15, 19, 23, 25]
#     unfeasible critical region detected
# Computing critical region for the active set [15, 19, 23, 25, 27]
# Computing critical region for the active set [14, 17, 21, 24, 26]
# Computing critical region for the active set [12, 19, 23, 25, 27]
# LICQ does not hold for the active set [0, 2, 15, 24, 26, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 2, 18, 24, 26, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 18, 24, 26, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 13, 25, 27, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 16, 25, 27, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 16, 25, 27, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 13, 17, 21, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [13, 14, 17, 21, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 15, 19, 23, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [12, 15, 19, 23, 25, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 14, 17, 21, 24, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 12, 19, 23, 25, 27]
#     unfeasible critical region detected
#
# Explicit solution computed in 3.46799182892 s:
# parameter space partitioned in 55 critical regions.

# %% [markdown]
# We can plot the consequent state partion, the optimal control law, and the optimal value function.

# %%
mpc_plt.state_partition(explicit_controller)
plt.show()

# %% [markdown]
# The Critical Regions with the same initial input can be merged as follows.

# %%
mpc_plt.grouped_state_partition(explicit_controller)
plt.show()
# Out:
# Critical regions grouped in  23  sets.

# %% [markdown]
# The result from the explicit solution and the optimal control problem is, of course, the same: let's take $x_0$ for example.

# %%
u_explicit, V_explicit = explicit_controller.feedforward(x_0)
u_implicit, V_implicit = controller.feedforward(x_0)
print('Explicit solution:\nu* = ' + str(u_explicit.flatten()) + ',\nV* = ' + str(V_explicit))
print('Implicit solution:\nu* = ' + str(u_implicit.flatten()) + ',\nV* = ' + str(V_implicit))
# Out:
# Explicit solution:
# u* = [-10.          -7.94778746  -5.64326588  -3.92547112  -3.36881054
#   -2.64123158],
# V* = 240.102874461
# Implicit solution:
# u* = [-10.         -7.94778746 -5.64326587 -3.92547112 -3.36881054 -2.64123158],
# V* = 240.102874461

# %% [markdown]
# We can also plot the feasible set of the mpQP, the optimal value function, and the state-space trajectory of the simulated trajectory.

# %%
controller.condensed_program.feasible_set.plot(facecolor='white', edgecolor='black')
mpc_plt.state_space_trajectory(x, color='red')
mpc_plt.optimal_value_function(explicit_controller)
plt.show()
