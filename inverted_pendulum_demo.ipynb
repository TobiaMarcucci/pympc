# %% [markdown]
# # Linear Inverted Pendulum MPC Demo

# %% [markdown]
# This is a demo for the Model Predictive Control (MPC) package $\texttt{mpc_tools}$.

# %%
# %load_ext autoreload
# %autoreload 2
#%pylab notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
from control import MPCController
from dynamical_systems import DTLinearSystem, plot_input_sequence, plot_state_trajectory, plot_state_space_trajectory
from geometry import Polytope

# %% [markdown]
# We stabilize a linear inverted pendulum with mass $m$ and length $l$, subject to the gravity acceleration $g$.

# %%
m = 1.
l = 1.
g = 10.

# %% [markdown]
# The linearized continuous-time dynamics is
# \begin{equation}
# \dot x = A x + B u =
# \begin{bmatrix}
# 0 & 1 \\ g/l & 0
# \end{bmatrix}
# x +
# \begin{bmatrix}
# 0 \\ 1/(ml^2)
# \end{bmatrix}
# u.
# \end{equation}
# The discrete-time linear system can be defined from its continuous-time representation setting a sampling time $t_s$ (the exact zero-order-hold discretization is used).

# %%
A = np.array([
    [0., 1.],
    [g/l, 0.]
])
B = np.array([
    [0.],
    [1/(m*l**2.)]
])
t_s = .1
sys = DTLinearSystem.from_continuous(t_s, A, B)

# %% [markdown]
# At each each step, the following optimal control is solved
# \begin{align}
# \min \quad &
# \sum_{k=0}^{N-1} (x_k^T Q x_k + u_k^T R u_k) + x_N^T P x_N \\
# \text{subject to} \quad & x_{k+1} = A x_k + B u_k, \quad k = 0,1,\ldots,N-1, \\
# & x_0 \ \text{given}, \\
# & u_k \in \mathcal U, \quad k = 0,1,\ldots,N-1, \\
# & x_k \in \mathcal X, \quad k = 1,2,\ldots,N-1, \\
# & x_N \in \mathcal X_N, \\
# \end{align}
# and the input $u_0$ is applied to the system.

# %%
N = 10
Q = np.eye(A.shape[0])
R = np.eye(B.shape[1])

# %% [markdown]
# For stability reasons we set the terminal cost to be equal to the cost-to-go of the infinite-horizon LQR controller. To do that wesolve the Discrete Algebraic Ricccati Equation (DARE)
# \begin{equation}
# P = (A+BK)^T P (A+BK) + Q + K^T R K
# \end{equation}
# where $K = -(B^T P B + R)^{-1} B^T P A$ is the optimal feedback $u_k = K x_k$.

# %%
P, K = sys.dare(Q, R)

# %% [markdown]
# The admissible sets $\mathcal U$ and $\mathcal X$ have to be polytopes. These can be generated from a set of linear inequalities (e.g., $C u_k \leq c$) or from bounds (e.g., $u_{max} \geq u_k \geq u_{min}$).

# %%
u_max = np.array([[10.]])
u_min = -u_max
U = Polytope.from_bounds(u_max, u_min)
U.assemble()
x_max = np.array([[1.], [1.]])
x_min = -x_max
X = Polytope.from_bounds(x_max, x_min)
X.assemble()

# %% [markdown]
# The terminal constraint $x_N \in \mathcal X_N$ is generally used to ensure closed-loop stability and, like $\mathcal U$ and $\mathcal X$, it has to be a polytope; here we decide to guarantee stability throught the use of the Maximum Output Admissible Set (MOAS).
#
# Defining the closed-loop state-transition matrix $ \bar A = A + BK$, constraining $x_N$ to be in the MOAS we ensure that $ x_{k+1} = \bar A x_k \in \mathcal{X}$ and $u_k = K x_k \in \mathcal{U}, \forall k \geq N$. This, together with the use of the DARE solution as terminal cost, is sufficient condition for the stability of the closed loop system.

# %%
X_N = sys.moas(K, X, U)

# %% [markdown]
# Now we have all the ingredients to build the MPC controller.

# %%
controller = MPCController(sys, N, Q, R, P, X, U, X_N)

# %% [markdown]
# We then simulate the closed loop system for $N_{sim}$ steps starting from the initial condition $x_0$.

# %%
N_sim = 50
x_0 = np.array([[.6],[1.]])
u = []
x = []
x.append(x_0)
for k in range(0, N_sim):
    u.append(controller.feedback(x[k]))
    x.append(sys.A.dot(x[k]) + sys.B.dot(u[k]))

# %% [markdown]
# We can plot the solution using the functions $\texttt{plot_input_sequence(.)}$ and $\texttt{plot_state_trajectory(.)}$

# %%
plot_input_sequence(u, t_s, N_sim, u_max, u_min)
plt.show()
plot_state_trajectory(x, t_s, N_sim, x_max, x_min)
plt.show()

# %% [markdown]
# We can get the explict solution of the optimal control problem, solving the resulting Multi-Parametric Quadratic Program (mpQP).

# %%
controller.compute_explicit_solution()
# Out:
# Computing critical region for the active set []
# Computing critical region for the active set [0]
# Computing critical region for the active set [1]
# Computing critical region for the active set [3]
# Computing critical region for the active set [5]
# Computing critical region for the active set [8]
# Computing critical region for the active set [9]
# LICQ does not hold for the active set [0, 5]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6]
# Computing critical region for the active set [0, 8]
# Computing critical region for the active set [0, 12]
# LICQ does not hold for the active set [1, 3]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7]
# Computing critical region for the active set [1, 9]
# Computing critical region for the active set [1, 13]
# Computing critical region for the active set [3, 8]
# Computing critical region for the active set [5, 9]
# LICQ does not hold for the active set [0, 5, 6]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10]
# Computing critical region for the active set [0, 6, 12]
# Computing critical region for the active set [0, 6, 16]
# LICQ does not hold for the active set [0, 3, 8]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 8, 12]
# LICQ does not hold for the active set [1, 3, 7]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11]
# Computing critical region for the active set [1, 7, 13]
# Computing critical region for the active set [1, 7, 17]
# LICQ does not hold for the active set [1, 5, 9]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 9, 13]
# LICQ does not hold for the active set [1, 3, 8]
#     unfeasible critical region detected
# Computing critical region for the active set [3, 8, 12]
# LICQ does not hold for the active set [0, 5, 9]
#     unfeasible critical region detected
# Computing critical region for the active set [5, 9, 13]
# LICQ does not hold for the active set [0, 5, 6, 10]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14]
# Computing critical region for the active set [0, 6, 10, 16]
# Computing critical region for the active set [0, 6, 10, 20]
# LICQ does not hold for the active set [0, 6, 8, 12]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 12, 16]
# LICQ does not hold for the active set [0, 3, 8, 12]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 8, 12, 16]
# LICQ does not hold for the active set [1, 3, 7, 11]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15]
# Computing critical region for the active set [1, 7, 11, 17]
# Computing critical region for the active set [1, 7, 11, 21]
# LICQ does not hold for the active set [1, 7, 9, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 13, 17]
# LICQ does not hold for the active set [1, 5, 9, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 9, 13, 17]
# LICQ does not hold for the active set [1, 3, 8, 12]
#     unfeasible critical region detected
# Computing critical region for the active set [3, 8, 12, 16]
# LICQ does not hold for the active set [0, 5, 9, 13]
#     unfeasible critical region detected
# Computing critical region for the active set [5, 9, 13, 17]
# LICQ does not hold for the active set [0, 5, 6, 10, 14]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18]
# Computing critical region for the active set [0, 6, 10, 14, 20]
# Computing critical region for the active set [0, 6, 10, 14, 24]
# LICQ does not hold for the active set [0, 6, 10, 12, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 16, 20]
# LICQ does not hold for the active set [0, 6, 8, 12, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 12, 16, 20]
# LICQ does not hold for the active set [0, 3, 8, 12, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 8, 12, 16, 20]
# LICQ does not hold for the active set [1, 3, 7, 11, 15]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19]
# Computing critical region for the active set [1, 7, 11, 15, 21]
# Computing critical region for the active set [1, 7, 11, 15, 25]
# LICQ does not hold for the active set [1, 7, 11, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 17, 21]
# LICQ does not hold for the active set [1, 7, 9, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 13, 17, 21]
# LICQ does not hold for the active set [1, 5, 9, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 9, 13, 17, 21]
# LICQ does not hold for the active set [1, 3, 8, 12, 16]
#     unfeasible critical region detected
# Computing critical region for the active set [3, 8, 12, 16, 20]
# LICQ does not hold for the active set [0, 5, 9, 13, 17]
#     unfeasible critical region detected
# Computing critical region for the active set [5, 9, 13, 17, 21]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18, 22]
# Computing critical region for the active set [0, 6, 10, 14, 18, 24]
# Computing critical region for the active set [0, 6, 10, 14, 18, 28]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 10, 14, 16, 20]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 20, 24]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 10, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 8, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 3, 8, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 8, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19, 23]
# Computing critical region for the active set [1, 7, 11, 15, 19, 25]
# Computing critical region for the active set [1, 7, 11, 15, 19, 29]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 11, 15, 17, 21]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 21, 25]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 11, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 9, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 9, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 5, 9, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 8, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [3, 4, 8, 12, 16, 20]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 9, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [2, 5, 9, 13, 17, 21]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18, 22]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18, 22, 26]
# Computing critical region for the active set [0, 6, 10, 14, 18, 22, 28]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 20, 24]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19, 23]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19, 23, 27]
# Computing critical region for the active set [1, 7, 11, 15, 19, 23, 29]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 21, 25]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22, 26]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18, 22, 26]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18, 22, 26, 30]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22, 28]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23, 27]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19, 23, 27]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19, 23, 27, 31]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23, 29]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22, 26, 30]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18, 22, 26, 30]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18, 22, 26, 30, 34]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23, 27, 31]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19, 23, 27, 31]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19, 23, 27, 31, 35]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22, 26, 30, 34]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18, 22, 26, 30, 34]
#     unfeasible critical region detected
# Computing critical region for the active set [0, 6, 10, 14, 18, 22, 26, 30, 34, 38]
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23, 27, 31, 35]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19, 23, 27, 31, 35]
#     unfeasible critical region detected
# Computing critical region for the active set [1, 7, 11, 15, 19, 23, 27, 31, 35, 39]
# LICQ does not hold for the active set [0, 4, 6, 10, 14, 18, 22, 26, 30, 34, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 5, 6, 10, 14, 18, 22, 26, 30, 34, 38]
#     unfeasible critical region detected
# LICQ does not hold for the active set [0, 6, 10, 14, 18, 22, 26, 30, 34, 38, 42]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 2, 7, 11, 15, 19, 23, 27, 31, 35, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 3, 7, 11, 15, 19, 23, 27, 31, 35, 39]
#     unfeasible critical region detected
# LICQ does not hold for the active set [1, 7, 11, 15, 19, 23, 27, 31, 35, 39, 43]
#     unfeasible critical region detected
#
# Explicit solution computed in 1.60116910934 s:
# parameter space partitioned in 69 critical regions.

# %% [markdown]
# We can plot the consequent state partion, the optimal control law, and the optimal value function.

# %%
controller.plot_state_partition()
plt.show()

# %% [markdown]
# The Critical Regions with the same initial input can be merged as follows.

# %%
controller.plot_merged_state_partition()
plt.show()
# Out:
# Critical regions merged in  7  sets.

# %% [markdown]
# The result from the explicit solution and the optimal control problem is, of course, the same: let's take $x_0$ for example.

# %%
u_explicit = controller.feedforward_explicit(x_0)
u_implicit = controller.feedforward(x_0)
print('Optimal control from the explicit solution: ' + str(u_explicit.flatten()))
print('Optimal control from the implicit solution: ' + str(u_implicit.flatten()))
# Out:
# Optimal control from the explicit solution: [-10.         -10.         -10.         -10.         -10.         -10.
#   -7.60244121  -5.54574353  -4.05447165  -2.97072552]
# Optimal control from the implicit solution: [-10.         -10.         -10.         -10.         -10.         -9.99999992
#  -7.60244126 -5.54574357 -4.05447168 -2.97072554]

# %% [markdown]
# We can also plot the feasible set of the mpQP, the optimal value function, and the state-space trajectory of the simulated trajectory.

# %%
controller.canonical_qp.feasible_set.plot(facecolor='white', edgecolor='black')
plot_state_space_trajectory(x)
controller.plot_optimal_value_function()
plt.show()
